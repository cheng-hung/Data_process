# %%
import glob
import os

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

# import seaborn as sns
import palettable.colorbrewer.diverging as pld
import palettable as pt

import numpy as np
import pandas as pd

# %matplotlib widget

# %%
plt.close('all')

# %%
## Plotting parameters

palette = pld.RdYlGn_4_r
# palette = pld.BlueGreen_4_r
palette = pld.Spectral_10_r
cmap = palette.mpl_colormap
cmap = plt.get_cmap('rainbow')
transparency = 0.7
labelsize = 20
spinewidth = 3
fontsize = 26
legendsize = 20
fontweight = 'bold'
labelpad = 6
pad = 10
linewidth = 2.5

# %%
import palettable
palette2 = palettable.colorbrewer.diverging.RdYlGn_8_r
RdYlGn_8_r = palette2.mpl_colormap
palette2.mpl_colors
# Out:
# [(0.10196078431372549, 0.596078431372549, 0.3137254901960784),
#  (0.4, 0.7411764705882353, 0.38823529411764707),
#  (0.6509803921568628, 0.8509803921568627, 0.41568627450980394),
#  (0.8509803921568627, 0.9372549019607843, 0.5450980392156862),
#  (0.996078431372549, 0.8784313725490196, 0.5450980392156862),
#  (0.9921568627450981, 0.6823529411764706, 0.3803921568627451),
#  (0.9568627450980393, 0.42745098039215684, 0.2627450980392157),
#  (0.8431372549019608, 0.18823529411764706, 0.15294117647058825)]

# %%
RdYlGn_8_r

# %%
palette2.hex_colors
# Out:
# ['#1A9850',
#  '#66BD63',
#  '#A6D96A',
#  '#D9EF8B',
#  '#FEE08B',
#  '#FDAE61',
#  '#F46D43',
#  '#D73027']

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = [
    # (0.25098039215686274, 0.0, 0.29411764705882354), 
    (0.4627450980392157, 0.16470588235294117, 0.5137254901960784),
    (0.3686274509803922, 0.30980392156862746, 0.6352941176470588), 
    (0.19607843137254902, 0.5333333333333333, 0.7411764705882353), 
    (0.4, 0.7607843137254902, 0.6470588235294118),
 # (0.6705882352941176, 0.8666666666666667, 0.6431372549019608),
 # (0.6509803921568628, 0.8509803921568627, 0.41568627450980394),
 # (0.10196078431372549, 0.5882352941176471, 0.2549019607843137), 
         ]
BlGn = LinearSegmentedColormap.from_list('BlGn', colors, N=100)
BlGn

# %%
RdGnpu_mpl_colors: list = [
    (0.4627450980392157, 0.16470588235294117, 0.5137254901960784),
    (0.3686274509803922, 0.30980392156862746, 0.6352941176470588), 
    (0.19607843137254902, 0.5333333333333333, 0.7411764705882353), 
    (0.4, 0.7607843137254902, 0.6470588235294118),
    
    (0.10196078431372549, 0.596078431372549, 0.3137254901960784), 
    
    # (0.4, 0.7411764705882353, 0.38823529411764707), 
    (0.6509803921568628, 0.8509803921568627, 0.41568627450980394), 
    (0.8509803921568627, 0.9372549019607843, 0.5450980392156862), 
    # (0.996078431372549, 0.8784313725490196, 0.5450980392156862), 
    (0.9921568627450981, 0.6823529411764706, 0.3803921568627451), 
    # (0.9568627450980393, 0.42745098039215684, 0.2627450980392157), 
    (0.8431372549019608, 0.18823529411764706, 0.15294117647058825), 
]
RdGnpu = LinearSegmentedColormap.from_list('RdGnpu', RdGnpu_mpl_colors, N=10000)
RdGnpu

# %%
from matplotlib.colors import rgb_to_hsv, to_hex
k = 9 #len(data_keys)
color_idx = np.linspace(0, 1, k)

# palette = pt.colorbrewer.sequential.GnBu_9
# cmap = RdGnpu.mpl_colormap
cmap = RdGnpu

i = 0
for kk in color_idx:
    hex_ = to_hex(cmap(kk))
    print(f'{i = }, {kk = }, {hex_ = }')
    i += 1
# Out:
# i = 0, kk = 0.0, hex_ = '#762a83'
# i = 1, kk = 0.125, hex_ = '#5e4fa2'
# i = 2, kk = 0.25, hex_ = '#3288bd'
# i = 3, kk = 0.375, hex_ = '#66c2a5'
# i = 4, kk = 0.5, hex_ = '#1a9850'
# i = 5, kk = 0.625, hex_ = '#a6d96a'
# i = 6, kk = 0.75, hex_ = '#d9ef8b'
# i = 7, kk = 0.875, hex_ = '#fdae61'
# i = 8, kk = 1.0, hex_ = '#d73027'

# %% [markdown]
# ## Find path of .fgr files (exported fitting results by PDFgui)

# %%
folder_base:str = '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/'
fgr_identifier:str = os.path.join(folder_base, '**.fgr')
fgr_path:list = glob.glob(fgr_identifier)
fgr_path.sort()
fgr_basename:list = [os.path.basename(n) for n in fgr_path]
print(*fgr_basename, sep='\n')
# Out:
# CsPbBr2-Cl_16micl_10m_20220331-004652_419192_primary-1_mean_q.fgr
# CsPbBr2-Cl_32micl_10m_20220331-001057_47942e_primary-1_mean_q.fgr
# CsPbBr2-Cl_64micl_10m_20220330-234135_b41155_primary-1_mean_q.fgr
# CsPbBr2-Cl_8micl_10m_20220331-013211_a7121b_primary-1_mean_q.fgr
# CsPbBr2-I_16micl_10m_20220331-174358_03721b_primary-1_mean_q.fgr
# CsPbBr2-I_32micl_10m_20220331-170247_0063a7_primary-1_mean_q.fgr
# CsPbBr2-I_64micl_10m_20220331-162851_06d064_primary-1_mean_q.fgr
# CsPbBr2-I_8micl_10m_20220331-181657_70819d_primary-1_mean_q.fgr
# CsPbBr3_CsPbBr2_10m.fgr

# %% [markdown]
# ## Find path of G(r)

# %%
folder_base:str = '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/'
gr_identifier:str = os.path.join(folder_base, 'Halide Exchange Data', 'CsPb**.gr')
gr_path:list = glob.glob(gr_identifier)
gr_path.sort()
gr_basename:list = [os.path.basename(n) for n in gr_path]
print(*gr_basename, sep='\n')
# Out:
# CsPbBr2-Cl_16micl_10m_20220331-004652_419192_primary-1_mean_q.gr
# CsPbBr2-Cl_32micl_10m_20220331-001057_47942e_primary-1_mean_q.gr
# CsPbBr2-Cl_64micl_10m_20220330-234135_b41155_primary-1_mean_q.gr
# CsPbBr2-Cl_8micl_10m_20220331-013211_a7121b_primary-1_mean_q.gr
# CsPbBr2-I_16micl_10m_20220331-174358_03721b_primary-1_mean_q.gr
# CsPbBr2-I_32micl_10m_20220331-170247_0063a7_primary-1_mean_q.gr
# CsPbBr2-I_64micl_10m_20220331-162851_06d064_primary-1_mean_q.gr
# CsPbBr2-I_8micl_10m_20220331-181657_70819d_primary-1_mean_q.gr
# CsPbBr2_10m_20220330-230818_e61560_primary-1_mean_q.gr

# %% [markdown]
# ## Organize data key and fgr path as a data dictonary

# %%
data_keys:list = ['Cl_64micl', 'Cl_32micl', 'Cl_16micl', 'Cl_8micl', 'CsPbBr2_10m', 'I_8micl', 'I_16micl', 'I_32micl', 'I_64micl']
data_dict:dict = {}
for key in data_keys:
    for _path in fgr_path:
        basename = os.path.basename(_path)
        if key in basename:
            data_dict.update({key: _path})

data_dict
# Out:
# {'Cl_64micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-Cl_64micl_10m_20220330-234135_b41155_primary-1_mean_q.fgr',
#  'Cl_32micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-Cl_32micl_10m_20220331-001057_47942e_primary-1_mean_q.fgr',
#  'Cl_16micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-Cl_16micl_10m_20220331-004652_419192_primary-1_mean_q.fgr',
#  'Cl_8micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-Cl_8micl_10m_20220331-013211_a7121b_primary-1_mean_q.fgr',
#  'CsPbBr2_10m': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr3_CsPbBr2_10m.fgr',
#  'I_8micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-I_8micl_10m_20220331-181657_70819d_primary-1_mean_q.fgr',
#  'I_16micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-I_16micl_10m_20220331-174358_03721b_primary-1_mean_q.fgr',
#  'I_32micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-I_32micl_10m_20220331-170247_0063a7_primary-1_mean_q.fgr',
#  'I_64micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_3/CsPbBr2-I_64micl_10m_20220331-162851_06d064_primary-1_mean_q.fgr'}

# %%
# data_keys:list = ['Cl_64micl', 'Cl_32micl', 'Cl_16micl', 'Cl_8micl', 'CsPbBr2_10m', 'I_8micl', 'I_16micl', 'I_32micl', 'I_64micl']
data_dict2:dict = {}
for key in data_keys:
    for _path in gr_path:
        basename = os.path.basename(_path)
        if key in basename:
            data_dict2.update({key: _path})

data_dict2
# Out:
# {'Cl_64micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-Cl_64micl_10m_20220330-234135_b41155_primary-1_mean_q.gr',
#  'Cl_32micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-Cl_32micl_10m_20220331-001057_47942e_primary-1_mean_q.gr',
#  'Cl_16micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-Cl_16micl_10m_20220331-004652_419192_primary-1_mean_q.gr',
#  'Cl_8micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-Cl_8micl_10m_20220331-013211_a7121b_primary-1_mean_q.gr',
#  'CsPbBr2_10m': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2_10m_20220330-230818_e61560_primary-1_mean_q.gr',
#  'I_8micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-I_8micl_10m_20220331-181657_70819d_primary-1_mean_q.gr',
#  'I_16micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-I_16micl_10m_20220331-174358_03721b_primary-1_mean_q.gr',
#  'I_32micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-I_32micl_10m_20220331-170247_0063a7_primary-1_mean_q.gr',
#  'I_64micl': '/Users/cheng-hunglin/Library/CloudStorage/GoogleDrive-chlin.tw1986@gmail.com/Other computers/My MacBook Pro/MAC_2015/Manuscript/In-Situ_Halide/processed_data_figures/Figure_1/Halide Exchange Data/CsPbBr2-I_64micl_10m_20220331-162851_06d064_primary-1_mean_q.gr'}

# %%
def is_float(s):    
    """
    Checks if a string can be successfully converted to a float.
    
    Args:
    s: The string to check.
    
    Returns:
    True if the string can be converted to a float, False otherwise.
    """
    try:
        float(s)
        return True
    except ValueError:
        return False

def get_HeaderRows(fn, sep=' ', num_data_column=2, check_range=100, check_float=True):

    cont_01 = []
    with open(fn, 'r') as f:
        cont = f.readlines()
        f.close()
    
    for line in cont:
        new_line = line.strip('\n').split(sep)
        cont_01.append(new_line)

    i = 0
    while i < len(cont_01):
        c0 = (len(cont_01[i]) == num_data_column)
        c1 = all([len(l)==num_data_column for l in cont_01[i:i+check_range]])
        c2 = (is_float(cont_01[i][0]) and is_float(cont_01[i][1]))

        if check_float:
            if c0 and c1 and c2:
                # print(f'Num of rows of header is {i}.')
                break
        else:
            if c0 and c1:
                # print(f'Num of rows of header is {i}.')
                break
            
        i += 1

    return i

# %%
## https://matplotlib.org/stable/gallery/lines_bars_and_markers/multicolored_line.html

from matplotlib.collections import LineCollection


def colored_line(x, y, c, ax, **lc_kwargs):
    """
    Plot a line with a color specified along the line by a third value.

    It does this by creating a collection of line segments. Each line segment is
    made up of two straight lines each connecting the current (x, y) point to the
    midpoints of the lines connecting the current point with its two neighbors.
    This creates a smooth line with no gaps between the line segments.

    Parameters
    ----------
    x, y : array-like
        The horizontal and vertical coordinates of the data points.
    c : array-like
        The color values, which should be the same size as x and y.
    ax : Axes
        Axis object on which to plot the colored line.
    **lc_kwargs
        Any additional arguments to pass to matplotlib.collections.LineCollection
        constructor. This should not include the array keyword argument because
        that is set to the color argument. If provided, it will be overridden.

    Returns
    -------
    matplotlib.collections.LineCollection
        The generated line collection representing the colored line.
    """
    if "array" in lc_kwargs:
        warnings.warn('The provided "array" keyword argument will be overridden')

    # Default the capstyle to butt so that the line segments smoothly line up
    default_kwargs = {"capstyle": "butt"}
    default_kwargs.update(lc_kwargs)

    # Compute the midpoints of the line segments. Include the first and last points
    # twice so we don't need any special syntax later to handle them.
    x = np.asarray(x)
    y = np.asarray(y)
    x_midpts = np.hstack((x[0], 0.5 * (x[1:] + x[:-1]), x[-1]))
    y_midpts = np.hstack((y[0], 0.5 * (y[1:] + y[:-1]), y[-1]))

    # Determine the start, middle, and end coordinate pair of each line segment.
    # Use the reshape to add an extra dimension so each pair of points is in its
    # own list. Then concatenate them to create:
    # [
    #   [(x1_start, y1_start), (x1_mid, y1_mid), (x1_end, y1_end)],
    #   [(x2_start, y2_start), (x2_mid, y2_mid), (x2_end, y2_end)],
    #   ...
    # ]
    coord_start = np.column_stack((x_midpts[:-1], y_midpts[:-1]))[:, np.newaxis, :]
    coord_mid = np.column_stack((x, y))[:, np.newaxis, :]
    coord_end = np.column_stack((x_midpts[1:], y_midpts[1:]))[:, np.newaxis, :]
    segments = np.concatenate((coord_start, coord_mid, coord_end), axis=1)

    lc = LineCollection(segments, **default_kwargs)
    lc.set_array(c)  # set the colors of each segment

    return ax.add_collection(lc)

# %% [markdown]
# ## Read fgr data into pandas

# %%
fgr_df:pd.DataFrame = pd.DataFrame()
fgr_df2:pd.DataFrame = pd.DataFrame()
for key, fn in data_dict.items():
    skiprows = get_HeaderRows(fn, sep=' ', num_data_column=5, check_range=100, check_float=True)
    df = pd.read_csv(fn, sep=' ', names=['r(A)', 'G(r)', 'd_r', 'd_Gr', 'Gdiff'], skiprows=skiprows)
    fgr_df[f'r_{key}'] = df['r(A)']
    fgr_df[f'g_{key}'] = df['G(r)']
    fgr_df[f'dr_{key}'] = df['d_r']
    fgr_df[f'dg_{key}'] = df['d_Gr']
    fgr_df[f'dif_{key}'] = df['Gdiff']

    fgr_df2[f'gr_{key}'] = df['G(r)']

fgr_df
# Out:
#       r_Cl_64micl  g_Cl_64micl  dr_Cl_64micl  dg_Cl_64micl  dif_Cl_64micl  \
# 0            2.49    -0.447408           0.0      0.108853       0.108853
# 1            2.50    -0.445507           0.0      0.122081       0.122081
# 2            2.51    -0.442208           0.0      0.133011       0.133011
# 3            2.52    -0.437318           0.0      0.141254       0.141254
# 4            2.53    -0.430647           0.0      0.146477       0.146477
# ...           ...          ...           ...           ...            ...
# 5747        59.96    -0.009754           0.0     -0.013807      -0.013807
# 5748        59.97    -0.009835           0.0     -0.017326      -0.017326
# 5749        59.98    -0.009929           0.0     -0.020474      -0.020474
# 5750        59.99    -0.010035           0.0     -0.023172      -0.023172
# 5751        60.00    -0.010153           0.0     -0.025354      -0.025354
#
#       r_Cl_32micl  g_Cl_32micl  dr_Cl_32micl  dg_Cl_32micl  dif_Cl_32micl  \
# 0            2.49    -0.431091           0.0      0.074957       0.074957
# 1            2.50    -0.430506           0.0      0.099074       0.099074
# 2            2.51    -0.428874           0.0      0.121449       0.121449
# 3            2.52    -0.426030           0.0      0.141483       0.141483
# 4            2.53    -0.421802           0.0      0.158619       0.158619
# ...           ...          ...           ...           ...            ...
# 5747        59.96    -0.012305           0.0     -0.018126      -0.018126
# 5748        59.97    -0.012252           0.0     -0.020723      -0.020723
# 5749        59.98    -0.012193           0.0     -0.022832      -0.022832
# 5750        59.99    -0.012128           0.0     -0.024412      -0.024412
# 5751        60.00    -0.012055           0.0     -0.025433      -0.025433
#
#       ...  r_I_32micl  g_I_32micl  dr_I_32micl  dg_I_32micl  dif_I_32micl  \
# 0     ...        2.49   -0.338116          0.0     0.032484      0.032484
# 1     ...        2.50   -0.338546          0.0     0.043524      0.043524
# 2     ...        2.51   -0.338597          0.0     0.054550      0.054550
# 3     ...        2.52   -0.338266          0.0     0.065299      0.065299
# 4     ...        2.53   -0.337551          0.0     0.075516      0.075516
# ...   ...         ...         ...          ...          ...           ...
# 5747  ...       59.96    0.003102          0.0     0.000234      0.000234
# 5748  ...       59.97    0.003051          0.0    -0.000053     -0.000053
# 5749  ...       59.98    0.002996          0.0    -0.000174     -0.000174
# 5750  ...       59.99    0.002936          0.0    -0.000124     -0.000124
# 5751  ...       60.00    0.002872          0.0     0.000100      0.000100
#
#       r_I_64micl  g_I_64micl  dr_I_64micl  dg_I_64micl  dif_I_64micl
# 0           2.49   -0.273249          0.0     0.040110      0.040110
# 1           2.50   -0.273714          0.0     0.052151      0.052151
# 2           2.51   -0.273852          0.0     0.063987      0.063987
# 3           2.52   -0.273662          0.0     0.075364      0.075364
# 4           2.53   -0.273148          0.0     0.086033      0.086033
# ...          ...         ...          ...          ...           ...
# 5747       59.96    0.000401          0.0    -0.003358     -0.003358
# 5748       59.97    0.000393          0.0    -0.003945     -0.003945
# 5749       59.98    0.000383          0.0    -0.004328     -0.004328
# 5750       59.99    0.000370          0.0    -0.004496     -0.004496
# 5751       60.00    0.000356          0.0    -0.004444     -0.004444
#
# [5752 rows x 45 columns]

# %% [markdown]
# ## Read gr data into pandas

# %%
gr_df:pd.DataFrame = pd.DataFrame()
gr_df2:pd.DataFrame = pd.DataFrame()
for key, fn in data_dict2.items():
    skiprows = get_HeaderRows(fn, sep=' ', num_data_column=2, check_range=100, check_float=True)
    df = pd.read_csv(fn, sep=' ', names=['r(A)', 'G(r)'], skiprows=skiprows)
    gr_df[f'r_{key}'] = df['r(A)']
    gr_df[f'g_{key}'] = df['G(r)']
    # fgr_df[f'dr_{key}'] = df['d_r']
    # fgr_df[f'dg_{key}'] = df['d_Gr']
    # fgr_df[f'dif_{key}'] = df['Gdiff']

    gr_df2[f'gr_{key}'] = df['G(r)']

gr_df
# Out:
#        r_Cl_64micl  g_Cl_64micl  r_Cl_32micl  g_Cl_32micl  r_Cl_16micl  \
# 0             0.00     0.000000         0.00     0.000000         0.00
# 1             0.01     0.002540         0.01     0.001241         0.01
# 2             0.02     0.004941         0.02     0.002360         0.02
# 3             0.03     0.007074         0.03     0.003243         0.03
# 4             0.04     0.008823         0.04     0.003790         0.04
# ...            ...          ...          ...          ...          ...
# 9996         99.96     0.008268        99.96     0.005462        99.96
# 9997         99.97     0.006158        99.97     0.003130        99.97
# 9998         99.98     0.003940        99.98     0.000751        99.98
# 9999         99.99     0.001678        99.99    -0.001610        99.99
# 10000       100.00    -0.000566       100.00    -0.003886       100.00
#
#        g_Cl_16micl  r_Cl_8micl  g_Cl_8micl  r_CsPbBr2_10m  g_CsPbBr2_10m  \
# 0         0.000000        0.00    0.000000           0.00       0.000000
# 1         0.002726        0.01   -0.000795           0.01       0.007334
# 2         0.005331        0.02   -0.001593           0.02       0.014406
# 3         0.007703        0.03   -0.002395           0.03       0.020972
# 4         0.009738        0.04   -0.003203           0.04       0.026801
# ...            ...         ...         ...            ...            ...
# 9996      0.004148       99.96    0.003926          99.96       0.001367
# 9997      0.003501       99.97    0.003629          99.97       0.001348
# 9998      0.002796       99.98    0.003284          99.98       0.001362
# 9999      0.002050       99.99    0.002898          99.99       0.001409
# 10000     0.001281      100.00    0.002482         100.00       0.001485
#
#        r_I_8micl  g_I_8micl  r_I_16micl  g_I_16micl  r_I_32micl  g_I_32micl  \
# 0           0.00   0.000000        0.00    0.000000        0.00    0.000000
# 1           0.01   0.014485        0.01    0.008352        0.01    0.006401
# 2           0.02   0.028479        0.02    0.016407        0.02    0.012578
# 3           0.03   0.041519        0.03    0.023883        0.03    0.018319
# 4           0.04   0.053170        0.04    0.030518        0.04    0.023428
# ...          ...        ...         ...         ...         ...         ...
# 9996       99.96   0.003817       99.96    0.000917       99.96   -0.001713
# 9997       99.97   0.003188       99.97    0.000055       99.97   -0.001865
# 9998       99.98   0.002522       99.98   -0.000804       99.98   -0.001957
# 9999       99.99   0.001841       99.99   -0.001632       99.99   -0.001989
# 10000     100.00   0.001164      100.00   -0.002407      100.00   -0.001959
#
#        r_I_64micl  g_I_64micl
# 0            0.00    0.000000
# 1            0.01    0.004873
# 2            0.02    0.009576
# 3            0.03    0.013946
# 4            0.04    0.017833
# ...           ...         ...
# 9996        99.96    0.002545
# 9997        99.97    0.002201
# 9998        99.98    0.001802
# 9999        99.99    0.001356
# 10000      100.00    0.000875
#
# [10001 rows x 18 columns]

# %%
data_keys[:4][::-1]
# Out:
# ['Cl_8micl', 'Cl_16micl', 'Cl_32micl', 'Cl_64micl']

# %%
Cl_keys = data_keys[:4][::-1]

# %%
data_keys[5:]
# Out:
# ['I_8micl', 'I_16micl', 'I_32micl', 'I_64micl']

# %%
I_keys = data_keys[5:]

# %%
# gr_fn = 'gr_halide_01.csv'
# gr_df.to_csv(gr_fn, sep=' ', index=False, float_format='{:.8e}'.format)

# %%
gr_df.corr(method='pearson', min_periods=2)
# Out:
#                r_Cl_64micl  g_Cl_64micl  r_Cl_32micl  g_Cl_32micl  \
# r_Cl_64micl       1.000000     0.013003     1.000000     0.014330
# g_Cl_64micl       0.013003     1.000000     0.013003     0.958954
# r_Cl_32micl       1.000000     0.013003     1.000000     0.014330
# g_Cl_32micl       0.014330     0.958954     0.014330     1.000000
# r_Cl_16micl       1.000000     0.013003     1.000000     0.014330
# g_Cl_16micl       0.013046     0.817170     0.013046     0.927247
# r_Cl_8micl        1.000000     0.013003     1.000000     0.014330
# g_Cl_8micl        0.012945     0.729817     0.012945     0.862025
# r_CsPbBr2_10m     1.000000     0.013003     1.000000     0.014330
# g_CsPbBr2_10m     0.010857     0.647572     0.010857     0.787276
# r_I_8micl         1.000000     0.013003     1.000000     0.014330
# g_I_8micl         0.012102     0.487433     0.012102     0.624968
# r_I_16micl        1.000000     0.013003     1.000000     0.014330
# g_I_16micl        0.015064     0.340791     0.015064     0.462567
# r_I_32micl        1.000000     0.013003     1.000000     0.014330
# g_I_32micl        0.016015     0.245027     0.016015     0.352758
# r_I_64micl        1.000000     0.013003     1.000000     0.014330
# g_I_64micl        0.018131     0.165512     0.018131     0.258042
#
#                r_Cl_16micl  g_Cl_16micl  r_Cl_8micl  g_Cl_8micl  \
# r_Cl_64micl       1.000000     0.013046    1.000000    0.012945
# g_Cl_64micl       0.013003     0.817170    0.013003    0.729817
# r_Cl_32micl       1.000000     0.013046    1.000000    0.012945
# g_Cl_32micl       0.014330     0.927247    0.014330    0.862025
# r_Cl_16micl       1.000000     0.013046    1.000000    0.012945
# g_Cl_16micl       0.013046     1.000000    0.013046    0.987584
# r_Cl_8micl        1.000000     0.013046    1.000000    0.012945
# g_Cl_8micl        0.012945     0.987584    0.012945    1.000000
# r_CsPbBr2_10m     1.000000     0.013046    1.000000    0.012945
# g_CsPbBr2_10m     0.010857     0.932431    0.010857    0.965749
# r_I_8micl         1.000000     0.013046    1.000000    0.012945
# g_I_8micl         0.012102     0.766021    0.012102    0.813646
# r_I_16micl        1.000000     0.013046    1.000000    0.012945
# g_I_16micl        0.015064     0.581141    0.015064    0.630648
# r_I_32micl        1.000000     0.013046    1.000000    0.012945
# g_I_32micl        0.016015     0.450579    0.016015    0.495137
# r_I_64micl        1.000000     0.013046    1.000000    0.012945
# g_I_64micl        0.018131     0.313830    0.018131    0.343358
#
#                r_CsPbBr2_10m  g_CsPbBr2_10m  r_I_8micl  g_I_8micl  r_I_16micl  \
# r_Cl_64micl         1.000000       0.010857   1.000000   0.012102    1.000000
# g_Cl_64micl         0.013003       0.647572   0.013003   0.487433    0.013003
# r_Cl_32micl         1.000000       0.010857   1.000000   0.012102    1.000000
# g_Cl_32micl         0.014330       0.787276   0.014330   0.624968    0.014330
# r_Cl_16micl         1.000000       0.010857   1.000000   0.012102    1.000000
# g_Cl_16micl         0.013046       0.932431   0.013046   0.766021    0.013046
# r_Cl_8micl          1.000000       0.010857   1.000000   0.012102    1.000000
# g_Cl_8micl          0.012945       0.965749   0.012945   0.813646    0.012945
# r_CsPbBr2_10m       1.000000       0.010857   1.000000   0.012102    1.000000
# g_CsPbBr2_10m       0.010857       1.000000   0.010857   0.912660    0.010857
# r_I_8micl           1.000000       0.010857   1.000000   0.012102    1.000000
# g_I_8micl           0.012102       0.912660   0.012102   1.000000    0.012102
# r_I_16micl          1.000000       0.010857   1.000000   0.012102    1.000000
# g_I_16micl          0.015064       0.749015   0.015064   0.940584    0.015064
# r_I_32micl          1.000000       0.010857   1.000000   0.012102    1.000000
# g_I_32micl          0.016015       0.611151   0.016015   0.846575    0.016015
# r_I_64micl          1.000000       0.010857   1.000000   0.012102    1.000000
# g_I_64micl          0.018131       0.452699   0.018131   0.703808    0.018131
#
#                g_I_16micl  r_I_32micl  g_I_32micl  r_I_64micl  g_I_64micl
# r_Cl_64micl      0.015064    1.000000    0.016015    1.000000    0.018131
# g_Cl_64micl      0.340791    0.013003    0.245027    0.013003    0.165512
# r_Cl_32micl      0.015064    1.000000    0.016015    1.000000    0.018131
# g_Cl_32micl      0.462567    0.014330    0.352758    0.014330    0.258042
# r_Cl_16micl      0.015064    1.000000    0.016015    1.000000    0.018131
# g_Cl_16micl      0.581141    0.013046    0.450579    0.013046    0.313830
# r_Cl_8micl       0.015064    1.000000    0.016015    1.000000    0.018131
# g_Cl_8micl       0.630648    0.012945    0.495137    0.012945    0.343358
# r_CsPbBr2_10m    0.015064    1.000000    0.016015    1.000000    0.018131
# g_CsPbBr2_10m    0.749015    0.010857    0.611151    0.010857    0.452699
# r_I_8micl        0.015064    1.000000    0.016015    1.000000    0.018131
# g_I_8micl        0.940584    0.012102    0.846575    0.012102    0.703808
# r_I_16micl       0.015064    1.000000    0.016015    1.000000    0.018131
# g_I_16micl       1.000000    0.015064    0.969504    0.015064    0.852083
# r_I_32micl       0.015064    1.000000    0.016015    1.000000    0.018131
# g_I_32micl       0.969504    0.016015    1.000000    0.016015    0.939810
# r_I_64micl       0.015064    1.000000    0.016015    1.000000    0.018131
# g_I_64micl       0.852083    0.018131    0.939810    0.018131    1.000000

# %%
data_keys
# Out:
# ['Cl_64micl',
#  'Cl_32micl',
#  'Cl_16micl',
#  'Cl_8micl',
#  'CsPbBr2_10m',
#  'I_8micl',
#  'I_16micl',
#  'I_32micl',
#  'I_64micl']

# %%
import scipy

x_min = 0
x_max = 4200

cor_list = []
for key in data_keys:
    cor = scipy.stats.pearsonr(gr_df['g_Cl_64micl'].iloc[x_min:x_max], gr_df[f'g_{key}'].iloc[x_min:x_max])
    cor_list.append(cor.statistic)
    print(cor)
# Out:
# PearsonRResult(statistic=0.9999999999999991, pvalue=0.0)
# PearsonRResult(statistic=0.9639155456016602, pvalue=0.0)
# PearsonRResult(statistic=0.831767259152265, pvalue=0.0)
# PearsonRResult(statistic=0.7492002815068135, pvalue=0.0)
# PearsonRResult(statistic=0.6670428498209601, pvalue=0.0)
# PearsonRResult(statistic=0.5033920107212443, pvalue=9.89853120686489e-269)
# PearsonRResult(statistic=0.35110777215254896, pvalue=4.09961811748574e-122)
# PearsonRResult(statistic=0.25144958539754064, pvalue=1.4094779562740371e-61)
# PearsonRResult(statistic=0.1669117689435582, pvalue=1.2810946746506442e-27)

# %%
cor.statistic
# Out:
# 0.1669117689435582

# %% [markdown]
# ## Plot data

# %%
gr_df[f'g_{data_keys[0]}']
# Out:
# 0        0.000000
# 1        0.002540
# 2        0.004941
# 3        0.007074
# 4        0.008823
#            ...
# 9996     0.008268
# 9997     0.006158
# 9998     0.003940
# 9999     0.001678
# 10000   -0.000566
# Name: g_Cl_64micl, Length: 10001, dtype: float64

# %%
gs = GridSpec(nrows=1, ncols=1,) #height_ratios=[1.0, 1.0])
f0 = plt.figure(figsize=(16, 8),) #constrained_layout=True)
ax0 = f0.add_subplot(gs[:,:])

k = len(data_keys)
color_idx = np.linspace(0, 1, k)

tick_font_size = 25
tick_width = 2.0
tick_length = 6.0
ax_linewidth = 2.0
linewidth = 2.5

# palette = pt.colorbrewer.sequential.GnBu_9
# cmap = RdGnpu.mpl_colormap
cmap = RdGnpu

y_offset = 0.2
x_min = 150
x_max = 4000

for i in range(0, k, 1):

    if i==3 or i==4:
        _offset = 0.8
    else:
        _offset = 0.2
        
    ax0.plot(gr_df[f'r_{data_keys[i]}'].iloc[x_min:x_max], 
             gr_df[f'g_{data_keys[i]}'].iloc[x_min:x_max]+y_offset, 
             label=f'{data_keys[i]}', 
             color=cmap(color_idx[i]), 
             linewidth=linewidth, )
    
    y_offset = y_offset + _offset

ax0.tick_params(labelsize=tick_font_size, width=tick_width, length=tick_length)

for axis in ['top', 'bottom', 'left', 'right']:
    ax0.spines[axis].set_linewidth(ax_linewidth) # Set the thickness in points

# ax0.legend(bbox_to_anchor=(1.0, 0.2), loc='lower left', ncol=1)
# ax0 = f0.add_subplot(gs[1,:])
# k = len(I_keys)
# color_idx = np.linspace(0, 1, k)

# palette = pt.colorbrewer.diverging.RdYlGn_11_r
# cmap = palette.mpl_colormap

# for i in range(0, k, 1):
#     ax0.plot(fgr_df[f'r_{I_keys[i]}'].iloc[x_min:x_max], 
#              fgr_df[f'g_{I_keys[i]}'].iloc[x_min:x_max]+y_offset*i, 
#              label=f'{I_keys[i]}', 
#              color=cmap(color_idx[i]))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fn_img = 'figure03_001.png'
# f0.savefig(fn_img, transparent=True, dpi=600)

# %%
from matplotlib.colors import rgb_to_hsv, to_hex
k = len(data_keys)
color_idx = np.linspace(0, 1, k)

# palette = pt.colorbrewer.sequential.GnBu_9
# cmap = RdGnpu.mpl_colormap
cmap = RdGnpu

i = 0
for kk in color_idx:
    hex_ = to_hex(cmap(kk))
    print(f'{i = }, {kk = }, {hex_ = }')
    i += 1
# Out:
# i = 0, kk = 0.0, hex_ = '#762a83'
# i = 1, kk = 0.125, hex_ = '#5e4fa2'
# i = 2, kk = 0.25, hex_ = '#3288bd'
# i = 3, kk = 0.375, hex_ = '#66c2a5'
# i = 4, kk = 0.5, hex_ = '#1a9850'
# i = 5, kk = 0.625, hex_ = '#a6d96a'
# i = 6, kk = 0.75, hex_ = '#d9ef8b'
# i = 7, kk = 0.875, hex_ = '#fdae61'
# i = 8, kk = 1.0, hex_ = '#d73027'

# %%
cmap(kk)[:3]
# Out:
# (0.8431372549019608, 0.18823529411764706, 0.15294117647058825)

# %%
# plt.close('all')

# %%
gs1 = GridSpec(nrows=2, ncols=2, height_ratios=[1.0, 0.6], width_ratios=[0.4, 1.0])
f1 = plt.figure(figsize=(16, 8),) #constrained_layout=True)
# ax1 = f1.add_subplot(gs1[:,:])

k = len(data_keys)
color_idx = np.linspace(0, 1, k)

tick_font_size = 24
tick_width = 2.0
tick_length = 6.0
ax_linewidth = 2.0
linewidth = 2.5

# palette = pt.colorbrewer.sequential.GnBu_9
# cmap = RdGnpu.mpl_colormap
cmap = RdGnpu

y_offset = 0.2
x_min = 20
x_max = 4000

ax1 = f1.add_subplot(gs1[0,:])
for i in range(0, k, 1):

    if i==3 or i==4:
        _offset = 0.8
    else:
        _offset = 0.2
        
    ax1.plot(gr_df[f'r_{data_keys[i]}'].iloc[x_min:x_max], 
             gr_df[f'g_{data_keys[i]}'].iloc[x_min:x_max]+y_offset, 
             label=f'{data_keys[i]}', 
             color=cmap(color_idx[i]), 
             linewidth=linewidth, 
            alpha=1.0, )
    
    y_offset = y_offset + _offset

ax1.set_xticks([0.0, 10.0, 20.0, 30.0, 40.0, ]) 
ax1.tick_params(labelsize=tick_font_size, width=tick_width, length=tick_length)

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(ax_linewidth) # Set the thickness in points



y_offset = 0.0
x_min = 2000
x_max = 4000

ax1 = f1.add_subplot(gs1[1,1])
for i in range(0, k, 1):

    if i==3 or i==4:
        _offset = 0.0 #0.8
    else:
        _offset = 0.0 #0.2
        
    ax1.plot(gr_df[f'r_{data_keys[i]}'].iloc[x_min:x_max], 
             gr_df[f'g_{data_keys[i]}'].iloc[x_min:x_max]+y_offset, 
             label=f'{data_keys[i]}', 
             color=cmap(color_idx[i]), 
             linewidth=linewidth, 
            alpha=0.7, )
    
    y_offset = y_offset + _offset

ax1.set_xticks([20, 30., 40.0, ]) 
ax1.set_yticks([]) 
ax1.tick_params(labelsize=tick_font_size, width=tick_width, length=tick_length)

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(ax_linewidth) # Set the thickness in points




ax1 = f1.add_subplot(gs1[1,0])
# data_label = ['Cl 64', '32', '16', 'Cl 8', 'Br', 'I 8', '16', '32', 'I 64']
data_label = ['Cl 64', '', 'Cl 16', '', 'Br', '', 'I 16', '', 'I 64']
# -------------- Create and show plot --------------
# Some arbitrary function that gives x, y, and color values
# t = np.linspace(-7.4, -0.5, 200)
x = range(len(data_label))
y = cor_list
k = len(data_label)
color = np.linspace(0, 1, k)

# Create a figure and plot the line on it
ax1.scatter(x, y, c=color, cmap=RdGnpu)
lines = colored_line(x, y, color, ax1, linewidth=linewidth, cmap=RdGnpu)

# ax1.plot(range(len(cor_list)), cor_list, linewidth=linewidth)

ax1.set_xticks(range(len(cor_list)), labels=data_label,
              rotation=30, ha="right", rotation_mode="anchor")
ax1.set_yticks([0.0, 0.5, 1.0])
ax1.set_ylim([-0.05, 1.1])
ax1.tick_params(labelsize=16, width=tick_width, length=tick_length)

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(ax_linewidth) # Set the thickness in points


f1.subplots_adjust(hspace=0.2)
f1.subplots_adjust(wspace=0.02)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fn_img = 'figure03_004.png'
# f1.savefig(fn_img, transparent=True, dpi=600)

# %%
# plt.close('all')

# %%
x_min = 1500
x_max = 4500
x = gr_df['r_Cl_64micl'].to_numpy()[x_min:x_max]
y = np.linspace(1, 9, 9)
X, Y = np.meshgrid(x, y)
Z = gr_df2.iloc[x_min:x_max].to_numpy().T
tick_font_size = 16
tick_width = 2.0
tick_length = 6.0
ax_linewidth = 2.0
linewidth = 2.5

# norm = mpl.colors.Normalize(vmin=np.percentile(Z, 0), vmax=np.percentile(Z, 100))
norm = mpl.colors.Normalize(vmin=-1.0, vmax=1.0, clip=True)

palette = pt.cmocean.sequential.Thermal_6
# palette = pt.colorbrewer.diverging.Spectral_11
# palette = pt.colorbrewer.sequential.YlGnBu_9
# palette = pt.lightbartlein.diverging.BlueOrange10_10
cmap = palette.mpl_colormap

# Create the pcolormesh plot
gs2 = GridSpec(nrows=1, ncols=1) #, width_ratios=[.3, .5, .5])
f2 = plt.figure(figsize=(9, 3))
ax2 = f2.add_subplot(gs[:,0])
mesh = ax2.pcolormesh(X, Y, Z, cmap=cmap, shading='gouraud', norm=norm)

ax2.tick_params(labelsize=tick_font_size, width=tick_width, length=tick_length)
# ax2.set_xticks([2.0, 3.0, 4.0])
# ax2.set_yticks([])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
