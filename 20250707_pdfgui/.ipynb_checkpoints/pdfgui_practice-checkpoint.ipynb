# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from diffpy.pdfgui.tui import LoadProject

# %%
# %matplotlib widget

# %%
fn = '/Users/cheng-hunglin/Documents/Data_LDRD/Cs_x-Pb_y-B_z.ddp'
ddp = LoadProject(fn)

# %%
LoadProject?
# Out:
# Init signature: LoadProject(filename=None)
# Docstring:
# Load and access data in pdfgui project file.
#
# Protected instance data:
#
# _project    -- instance of PDFGuiControl with loaded project file.
# Init docstring:
# Initialize LoadProject object, by reading existing project file.
#
# filename -- path to PDFgui project file.
# File:           /opt/miniconda3/envs/pdfgui_313/lib/python3.13/site-packages/diffpy/pdfgui/tui.py
# Type:           type
# Subclasses:

# %%
dir(ddp)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_project',
#  'getCalculations',
#  'getDataSets',
#  'getDopings',
#  'getFits',
#  'getPhases',
#  'getTemperatures',
#  'load',
#  'save']

# %%
ddp.getDataSets()

# %%
dataset_03 = ddp.getDataSets()[3]
robs = dataset_03.getData('robs')
Gobs = dataset_03.getData('Gobs')
rcalc = dataset_03.getData('rcalc')
Gcalc = dataset_03.getData('Gcalc')

# %%
plt.figure()
plt.plot(robs, Gobs, label='observation')
plt.plot(rcalc, Gcalc, 'r.', label='calculation')
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_03 = ddp.getFits()[5]
fit_03

# %%
fit_03.name
# Out:
# 'Fit 3 _3D_copy'

# %%
fit_03.parameters
# Out:
# {1: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5450>,
#  2: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf52d0>,
#  3: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf53d0>,
#  100: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5350>,
#  5: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5250>,
#  6: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf51d0>,
#  40: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5150>,
#  41: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf50d0>,
#  42: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5050>,
#  300: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4fd0>,
#  200: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4f50>,
#  50: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4ed0>,
#  51: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4e50>,
#  52: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4dd0>,
# ...

# %%
fit_03.dataNameDict
# Out:
# {'p_CsBr.cif': {'u11(1)': 271,
#   'delta2': 272,
#   'u11(2)': 273,
#   'lat(3)': 274,
#   'u22(2)': 275,
#   'u33(1)': 276,
#   'lat(1)': 277,
#   'pscale': 278,
#   'u22(1)': 279,
#   'lat(2)': 280,
#   'u33(2)': 281},
#  'p_CsPbBr3.cif': {'u22(13)': 3,
#   'u11(2)': 4,
#   'u22(11)': 5,
#   'u33(15)': 6,
#   'u22(17)': 7,
#   'pscale': 8,
#   'u33(20)': 67,
#   'u11(4)': 9,
#   'u33(3)': 10,
#   'u22(6)': 11,
#   'u11(6)': 12,
#   'u33(5)': 13,
#   'u22(4)': 14,
#   'u33(7)': 15,
#   'u11(14)': 16,
#   'u22(19)': 17,
#   'lat(2)': 18,
#   'u11(16)': 19,
#   'u33(17)': 20,
#   'u11(18)': 21,
#   'u22(3)': 22,
#   'u22(20)': 23,
#   'u33(8)': 24,
#   'u11(10)': 25,
#   'u22(15)': 26,
#   'u11(8)': 27,
#   'u33(11)': 28,
#   'u11(12)': 29,
#   'u33(19)': 30,
#   'u33(13)': 31,
#   'u11(20)': 32,
#   'u33(18)': 33,
#   'u11(1)': 34,
#   'delta2': 35,
#   'u22(12)': 36,
#   'u11(3)': 37,
#   'u22(10)': 38,
#   'u33(14)': 39,
#   'u33(2)': 40,
#   'u22(8)': 63,
#   'u22(1)': 42,
# ...

# %%
dir(fit_03.datasets)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'items',
#  'keys',
#  'pop',
#  'remove',
#  'rename',
#  'reverse',
#  'sort',
#  'values']

# %%
fit_03.datasets.keys()
# Out:
# ['Cs_078_Br_092_Pb_000_OLA_020_PF_016_Tol_948_20250608-191128_dc413d_scattering-1_mean_q.gr']

# %%
fit_03.datasets.items()
# Out:
# [('Cs_078_Br_092_Pb_000_OLA_020_PF_016_Tol_948_20250608-191128_dc413d_scattering-1_mean_q.gr',
#   <diffpy.pdfgui.control.fitdataset.FitDataSet at 0x11ebdc8a0>)]

# %%
fit_03.datasets.values()

# %%
fit_03.datasets[0]

# %%
dir(fit_03.datasets[0])
# Out:
# ['Gcalc',
#  'Gdiff',
#  'Gobs',
#  'Gtrunc',
#  '_Gcalc',
#  '_Gtrunc',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_crw',
#  '_dGcalc',
#  '_dGtrunc',
#  '_fitrmax',
#  '_fitrmin',
#  '_fitrstep',
#  '_getStrId',
#  '_get_Gcalc',
#  '_get_Gdiff',
#  '_get_Gtrunc',
#  '_get_crw',
#  '_get_dGcalc',
#  '_get_dGtrunc',
#  '_get_fitrmax',
#  '_get_fitrmin',
#  '_get_fitrstep',
#  '_get_rcalc',
#  '_rcalc',
#  '_rcalc_changed',
#  '_resampledPDFDataSet',
#  '_set_Gcalc',
#  '_set_Gtrunc',
#  '_set_crw',
#  '_set_dGcalc',
# ...

# %%
fit_03.datasets[0].qdamp
# Out:
# 0.032

# %%
fit_03.datasets[0].constraints['dscale']

# %%
fit_03.datasets[0].rmax
# Out:
# 100.0

# %%
fit_03.datasets[0].fitrmax
# Out:
# 60.0

# %%
fit_03.datasets[0]._crw
# Out:
# []

# %%
fit_03.getData('rw')
# Out:
# 0.16978607070824575

# %%
fit_03.getData(1)
# Out:
# 13.736110779492142

# %%
fit_03.getData(2)
# Out:
# 17.415653098761428

# %%
fit_03.getData(300)
# Out:
# 0.2056985386911079

# %%
fit_03.parameters
# Out:
# {1: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf47d0>,
#  2: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf7ed0>,
#  3: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf5d50>,
#  100: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf7f50>,
#  101: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf41d0>,
#  6: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf45d0>,
#  40: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4550>,
#  41: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf44d0>,
#  202: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4450>,
#  43: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf43d0>,
#  300: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4350>,
#  200: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf42d0>,
#  50: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4250>,
#  51: <diffpy.pdfgui.control.parameter.Parameter at 0x11ebf4150>,
# ...

# %%
fit_03.parameters[1].fixed
# Out:
# False

# %%
fit_03.parameters[200].fixed
# Out:
# True

# %%
fit_03.parameters[1].initialValue()
# Out:
# 13.7361107795

# %%
dir(fit_03.strucs[0])
# Out:
# ['B11',
#  'B12',
#  'B13',
#  'B22',
#  'B23',
#  'B33',
#  'Bisoequiv',
#  'U',
#  'U11',
#  'U12',
#  'U13',
#  'U22',
#  'U23',
#  'U33',
#  'Uisoequiv',
#  '_Structure__emptySharedStructure',
#  '__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_allowed_pdffit_vars',
# ...

# %%
fit_03.strucs[0].xyz
# Out:
# array([[0. , 0. , 0. ],
#        [0.5, 0.5, 0.5]])

# %%
fit_03.strucs[0].getvar('spdiameter')
# Out:
# 0.0

# %%
fit_03.strucs[0].getvar('pscale')
# Out:
# 1.0

# %%
fit_03.strucs[0].getvar('lat(1)')
# Out:
# 4.28963

# %%
fit_03.strucs[0].getvar('lat(4)')
# Out:
# 90.0

# %%
fit_03

# %%
fit_03.datasets[0]

# %%
fit_03.datasets[0].constraints
# Out:
# {'dscale': <diffpy.pdfgui.control.constraint.Constraint at 0x11fbdb950>}

# %%
fit_02 = ddp.getFits()[4]

# %%
fit_02.datasets[0].constraints
# Out:
# {'dscale': <diffpy.pdfgui.control.constraint.Constraint at 0x11f911d30>}
