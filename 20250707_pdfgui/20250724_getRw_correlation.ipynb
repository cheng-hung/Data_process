# %% [markdown]
# # This notebook does the following things:
# # 1. Extract rW from PDFgui project file (.ddp or .ddp3)
# # 2. Calculate the Pearson correlation coefficient

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy
from diffpy.pdfgui.tui import LoadProject
from diffpy.pdfgui.control.pdfguicontrol import PDFGuiControl
from diffpy.pdffit2.pdffit2 import calculationError

from IPython.display import clear_output
# from tqdm.auto import tqdm
import time
import shutil
import yaml

# %%
def get_uid_by_fn(fn, uid_idx=-4, sep='_', ):
    fn_basename = os.path.basename(str(fn))
    split_list = fn_basename.split(sep)
    uid = split_list[uid_idx]
    return uid

# %%
def get_item_string(str_obj, sep='  '):
    ii = str_obj.split(sep)
    item_list = [x.lstrip(' ') for x in ii if x != '']
    return item_list

def get_phase_content(fitting_obj, num_phase=3, content_key='Relative phase content in terms of'):
    ## example of fitting_obj: xxxx.getfFts()[i] if read a ddp file
    ##                     or: xxxx.fits[i] if created from PDFGuiControl()

    result = fitting_obj.res
    res_split = result.split('\n')

    for s in res_split:
        if content_key in s:
            s_idx = res_split.index(s)

    phase_content = {}
    key_list = get_item_string(res_split[s_idx+1], sep='  ')

    content_list=[]
    for i in range(num_phase):
        phase_i = get_item_string(res_split[s_idx+2+i], sep=' ')
        if phase_i[3] == '0':
            phase_ii = [float(j) for j in phase_i[3:]]
        else:
            phase_ii = [float(j) for j in phase_i[3::2]]
        content_list.append(phase_ii)

    content_array = np.asarray(content_list, dtype=np.float32)
    for i in range(num_phase):
        d = {f'{key_list[i]}':[c for c in content_array[:,i]]}
        phase_content.update(d)

    return phase_content


def get_rw_in_result(fitting_obj, content_key='Rw - value'):
    result = fitting_obj.res
    res_split = result.split('\n')

    for s in res_split:
        if content_key in s:
            s_idx = res_split.index(s)
    
    rw = res_split[s_idx].split(' ')[-1]
    return float(rw)

# %%
def index_uid_list(uid, uid_array, print_info=True):
    uid_array = np.asarray(uid_array)

    idx_list = []
    for idx in range(uid_array.shape[0]):
        if uid in uid_array[idx]:
            idx_list.append(idx)
            
    if print_info:
        
        if len(idx_list) == 1:
            print(f'Only found one corresponding uid {idx_list = }. It is good.')
    
        elif len(idx_list) > 1:
            print('Found more than one coorespnding uids. Need further check.')
    
        elif len(idx_list) == 0:
            print('Cannot find the corresponding uid. Need further check.')
    
    return idx_list

# %% [markdown]
# ## Get uids from an Excel spreadsheet

# %%
xlsx_dir = '/Users/cheng-hunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/LDRD_PQDs_log'
xlsx_name = 'blop_test_20250724.xlsx'
xlsx_fn = os.path.join(xlsx_dir, xlsx_name)

# %%
xlsx = pd.read_excel(xlsx_fn, sheet_name='20250606_XPD_beamtime', header=1, )
xlsx
# Out:
#     Cs-rich 33mM  TOABr 66 mM  Pb-rich 33mM  20%OLA 66mM  Unnamed: 4  PLQY  \
# 0          20.00        40.00        180.00         0.00         NaN  0.30
# 1         180.00        40.00         20.00         0.00         NaN  0.13
# 2          80.00        80.00         80.00         0.00         NaN  0.26
# 3          20.00        80.00        140.00         0.00         NaN  0.20
# 4         140.00        80.00         20.00         0.00         NaN  0.24
# ..           ...          ...           ...          ...         ...   ...
# 89         20.00        70.00         22.00         0.00         NaN  0.14
# 90         35.45       162.02         83.42        37.64         NaN   NaN
# 91         18.00        80.00         40.00        18.00         NaN   NaN
# 92         30.00        90.00         50.00         5.00         NaN   NaN
# 93         19.00        82.00         43.00         2.00         NaN   NaN
#
#     Peak (nm)  FWHM (nm)  CsBr.gr correlation  Cs4PbBr6.gr correlation  \
# 0      512.51      24.24                0.355                    0.391
# 1      512.88      28.38                0.769                    0.515
# 2      513.80      25.20                0.412                    0.475
# 3      514.93      23.33                0.254                    0.376
# 4      514.28      25.27                0.822                    0.540
# ..        ...        ...                  ...                      ...
# 89     516.26      21.64                0.249                    0.601
# 90        NaN        NaN                  NaN                      NaN
# 91        NaN        NaN                  NaN                      NaN
# 92        NaN        NaN                  NaN                      NaN
# 93        NaN        NaN                  NaN                      NaN
#
#     CsPbBr3.gr correlation Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0                    0.548         NaN          NaN          NaN          NaN
# 1                    0.281         NaN          NaN          NaN          NaN
# 2                    0.645         NaN          NaN          NaN          NaN
# 3                    0.648         NaN          NaN          NaN          NaN
# 4                    0.338         NaN          NaN          NaN          NaN
# ..                     ...         ...          ...          ...          ...
# 89                   0.637         NaN          NaN          NaN          NaN
# 90                     NaN         NaN          NaN          NaN          NaN
# 91                     NaN         NaN          NaN          NaN          NaN
# 92                     NaN         NaN          NaN          NaN          NaN
# 93                     NaN         NaN          NaN          NaN          NaN
#
#     Unnamed: 15                                   UID
# 0           NaN  c1a394d2-4436-404c-8cf7-7ea7d886b27e
# 1           NaN  9e13eba9-85a6-420b-bbf2-92d035c8c4ec
# 2           NaN  d03d556a-29e5-4fbb-96eb-71cc843f4a3a
# 3           NaN  a26ebc5e-387e-45ac-b555-d0889ae15126
# 4           NaN  2047e3cc-0b3f-4556-af59-d1f4558de3a2
# ..          ...                                   ...
# 89          NaN                              a9aa8a79
# 90          NaN                                   NaN
# 91          NaN                                   NaN
# 92          NaN                                   NaN
# 93          NaN                                   NaN
#
# [94 rows x 17 columns]

# %%
xlsx['UID'].shape
# Out:
# (94,)

# %%
xlsx_uid_array = xlsx['UID'].dropna().to_numpy()
xlsx_uid_array.shape
# Out:
# (90,)

# %% [markdown]
# ## Load ddp project files to get rW and phase scale

# %%
ddp_dir = '/Users/cheng-hunglin/Documents/Data_LDRD'
day1_name = 'Cs_x-Pb_y-B_z_serial_bkg_10min_22-1.ddp.ddp3'
day3_name = 'Cs_x-Pb_y-B_z_serial_bkg_day3_22-1.ddp.ddp3'
day4_name = 'Cs_x-Pb_y-B_z_serial_bkg_day4_22-1.ddp.ddp3'

fn_10min = os.path.join(ddp_dir, day1_name)
fn_day3 = os.path.join(ddp_dir, day3_name)
fn_day4 = os.path.join(ddp_dir, day4_name)

# %%
ddp_10min = LoadProject(fn_10min)
ddp_day3 = LoadProject(fn_day3)
ddp_day4 = LoadProject(fn_day4)

# %%
rw = ddp_10min.getFits()[2].getData('rw')

# %%
rw
# Out:
# 0.45467085458089257

# %%
fn = ddp_10min.getFits()[1].datasets.keys()[0]

# %%
type(ddp_10min.getFits())
# Out:
# list

# %%
get_uid_by_fn(fn)
# Out:
# '91db25'

# %%
len(ddp_10min.getFits())
# Out:
# 38

# %%
from numpy.dtypes import StringDType

rw_array = np.zeros(xlsx_uid_array.shape)
CsBr_array = np.zeros(xlsx_uid_array.shape)
Cs4PbBr6_array = np.zeros(xlsx_uid_array.shape)
CsPbBr3_array = np.zeros(xlsx_uid_array.shape)
ddp_uid_array = np.empty(xlsx_uid_array.shape, dtype=StringDType())
fn_array = np.empty(xlsx_uid_array.shape, dtype=StringDType())

# %%
rw_array.shape
# Out:
# (90,)

# %%
check_uid = []
total_pdffit2 = ddp_10min.getFits() + ddp_day3.getFits() + ddp_day4.getFits()

for i in range(len(total_pdffit2)):
# for i in range(5):
    fn = total_pdffit2[i].datasets.keys()[0]
    
    rw = get_rw_in_result(total_pdffit2[i])
    phase_content = get_phase_content(total_pdffit2[i])

    print(fn, rw)
    
    uid_fit = get_uid_by_fn(fn)
    idx_list = index_uid_list(uid_fit, xlsx_uid_array)

    print('\n')
    
    if len(idx_list) == 0:
        check_uid.append(uid_fit)
    
    else:
        fn_array[idx_list[0]] = fn
        rw_array[idx_list[0]] = rw
        ddp_uid_array[idx_list[0]] = uid_fit
        CsBr_array[idx_list[0]] = phase_content['mass'][0]
        Cs4PbBr6_array[idx_list[0]] = phase_content['mass'][1]
        CsPbBr3_array[idx_list[0]] = phase_content['mass'][2]
# Out:
# Cs_060_Br_120_Pb_060_PF_020_Tol_1200_20250606-233737_992618_scattering-1_mean_q.gr 0.262066
# Only found one corresponding uid idx_list = [5]. It is good.
#
#
# Cs_000_Br_100_Pb_100_OLA_020_PF_018_Tol_1100_20250607-195546_91db25_scattering-1_mean_q.gr 0.453689
# Only found one corresponding uid idx_list = [20]. It is good.
#
#
# Cs_000_Br_120_Pb_060_OLA_005_PF_015_Tol_925_20250607-210829_ee525f_scattering-1_mean_q.gr 0.454671
# Only found one corresponding uid idx_list = [22]. It is good.
#
#
# Cs_000_Br_120_Pb_120_PF_020_Tol_1200_20250607-021742_d0b4bc_scattering-1_mean_q.gr 0.451138
# Only found one corresponding uid idx_list = [9]. It is good.
#
#
# Cs_000_Br_180_Pb_060_PF_020_Tol_1200_20250607-023725_6129b4_scattering-1_mean_q.gr 0.609117
# Only found one corresponding uid idx_list = [10]. It is good.
#
#
# Cs_005_Br_040_Pb_010_OLA_000_PF_005_Tol_275_20250607-220713_6c0aea_scattering-1_mean_q.gr 0.305446
# Only found one corresponding uid idx_list = [23]. It is good.
#
#
# Cs_010_Br_080_Pb_110_OLA_010_PF_018_Tol_1050_20250607-193446_ed358a_scattering-1_mean_q.gr 0.358669
# Only found one corresponding uid idx_list = [19]. It is good.
#
#
# Cs_020_Br_040_Pb_180_PF_020_Tol_1200_20250606-215430_c1a394_scattering-1_mean_q.gr 0.498661
# Only found one corresponding uid idx_list = [0]. It is good.
#
#
# Cs_020_Br_060_Pb_100_OLA_060_PF_020_Tol_1200_20250607-155132_8b795a_scattering-1_mean_q.gr 0.49738
# Only found one corresponding uid idx_list = [15]. It is good.
#
#
# Cs_020_Br_080_Pb_140_OLA_005_PF_020_Tol_1225_20250608-001801_0bfd55_scattering-1_mean_q.gr 0.297829
# Only found one corresponding uid idx_list = [29]. It is good.
#
#
# Cs_020_Br_080_Pb_140_PF_020_Tol_1200_20250606-225646_a26ebc_scattering-1_mean_q.gr 0.376581
# Only found one corresponding uid idx_list = [3]. It is good.
#
#
# Cs_020_Br_090_Pb_140_OLA_020_PF_022_Tol_1350_20250608-010011_e27e88_scattering-1_mean_q.gr 0.348258
# Only found one corresponding uid idx_list = [31]. It is good.
#
#
# Cs_020_Br_100_Pb_100_OLA_020_PF_020_Tol_1200_20250607-150924_99c5e0_scattering-1_mean_q.gr 0.427648
# Only found one corresponding uid idx_list = [13]. It is good.
#
#
# Cs_020_Br_120_Pb_100_PF_020_Tol_1200_20250607-013724_4d8520_scattering-1_mean_q.gr 0.267686
# Only found one corresponding uid idx_list = [6]. It is good.
#
#
# Cs_024_Br_070_Pb_003_OLA_020_PF_010_Tol_589_20250607-233423_e65c02_scattering-1_mean_q.gr 0.325553
# Only found one corresponding uid idx_list = [27]. It is good.
#
#
# Cs_025_Br_080_Pb_135_OLA_010_PF_021_Tol_1250_20250608-003913_629b0d_scattering-1_mean_q.gr 0.321884
# Only found one corresponding uid idx_list = [30]. It is good.
#
#
# Cs_032_Br_059_Pb_079_OLA_023_PF_016_Tol_967_20250607-231051_620d4e_scattering-1_mean_q.gr 0.357139
# Only found one corresponding uid idx_list = [26]. It is good.
#
#
# Cs_040_Br_100_Pb_080_OLA_020_PF_020_Tol_1200_20250607-183029_2ea4da_scattering-1_mean_q.gr 0.362031
# Only found one corresponding uid idx_list = [17]. It is good.
#
#
# Cs_041_Br_092_Pb_013_OLA_044_PF_016_Tol_954_20250607-235646_d0803c_scattering-1_mean_q.gr 0.323024
# Only found one corresponding uid idx_list = [28]. It is good.
#
#
# Cs_060_Br_060_Pb_060_OLA_060_PF_020_Tol_1200_20250607-161229_50fbde_scattering-1_mean_q.gr 0.443992
# Only found one corresponding uid idx_list = [16]. It is good.
#
#
# Cs_060_Br_100_Pb_060_OLA_020_PF_020_Tol_1200_20250607-153019_7ac162_scattering-1_mean_q.gr 0.290175
# Only found one corresponding uid idx_list = [14]. It is good.
#
#
# Cs_060_Br_120_Pb_060_PF_020_Tol_1200_20250606-233737_992618_scattering-1_mean_q.gr 0.262076
# Only found one corresponding uid idx_list = [5]. It is good.
#
#
# Cs_080_Br_040_Pb_100_OLA_020_PF_020_Tol_1200_20250607-185124_26d97d_scattering-1_mean_q.gr 0.39817
# Only found one corresponding uid idx_list = [18]. It is good.
#
#
# Cs_080_Br_080_Pb_080_PF_020_Tol_1200_20250606-223512_d03d55_scattering-1_mean_q.gr 0.326182
# Only found one corresponding uid idx_list = [2]. It is good.
#
#
# Cs_100_Br_000_Pb_100_OLA_040_PF_020_Tol_1200_20250607-132022_3ae92b_scattering-1_mean_q.gr 0.663049
# Cannot find the corresponding uid. Need further check.
#
#
# Cs_100_Br_020_Pb_100_OLA_020_PF_020_Tol_1200_20250607-135907_cd7e20_scattering-1_mean_q.gr 0.593692
# Cannot find the corresponding uid. Need further check.
#
#
# Cs_100_Br_120_Pb_020_PF_020_Tol_1200_20250607-015745_e4b5eb_scattering-1_mean_q.gr 0.171292
# Only found one corresponding uid idx_list = [7]. It is good.
#
#
# Cs_113_Br_086_Pb_033_OLA_000_PF_019_Tol_1159_20250607-222808_ca1d54_scattering-1_mean_q.gr 0.205521
# Only found one corresponding uid idx_list = [24]. It is good.
#
#
# Cs_116_Br_084_Pb_034_OLA_005_PF_020_Tol_1198_20250607-224919_5cd92f_scattering-1_mean_q.gr 0.228118
# Only found one corresponding uid idx_list = [25]. It is good.
#
#
# Cs_120_Br_080_Pb_025_OLA_020_PF_020_Tol_1225_20250608-020457_4cd305_scattering-1_mean_q.gr 0.257464
# Only found one corresponding uid idx_list = [34]. It is good.
#
#
# Cs_120_Br_120_Pb_000_OLA_060_PF_025_Tol_1500_20250607-201612_61ff18_scattering-1_mean_q.gr 0.236434
# Only found one corresponding uid idx_list = [21]. It is good.
#
#
# Cs_140_Br_070_Pb_020_OLA_010_PF_020_Tol_1200_20250608-014242_08e90c_scattering-1_mean_q.gr 0.251361
# Only found one corresponding uid idx_list = [33]. It is good.
#
#
# Cs_140_Br_080_Pb_020_PF_020_Tol_1200_20250606-231709_2047e3_scattering-1_mean_q.gr 0.233113
# Only found one corresponding uid idx_list = [4]. It is good.
#
#
# Cs_155_Br_080_Pb_015_OLA_005_PF_021_Tol_1275_20250608-012121_c172aa_scattering-1_mean_q.gr 0.215812
# Only found one corresponding uid idx_list = [32]. It is good.
#
#
# Cs_180_Br_040_Pb_020_PF_020_Tol_1200_20250606-221450_9e13eb_scattering-1_mean_q.gr 0.421203
# Only found one corresponding uid idx_list = [1]. It is good.
#
#
# Cs_rich_1-0-1_20250606-164700_db00fc_primary-1_mean_q.gr 0.126442
# Only found one corresponding uid idx_list = [8]. It is good.
#
#
# Cs_rich_1-0-1_80uL_20250606-211441_860dbf_primary-1_mean_q.gr 0.116686
# Only found one corresponding uid idx_list = [12]. It is good.
#
#
# Cs_rich_1-0-1_v2_20250606-182331_854c30_primary-1_mean_q.gr 0.11297
# Only found one corresponding uid idx_list = [11]. It is good.
#
#
# Cs_060_Br_120_Pb_060_PF_020_Tol_1200_20250606-233737_992618_scattering-1_mean_q.gr 0.262076
# Only found one corresponding uid idx_list = [5]. It is good.
#
#
# Cs_000_Br_040_Pb_058_OLA_026_PF_010_Tol_620_20250608-175222_4e1986_scattering-1_mean_q.gr 0.776852
# Only found one corresponding uid idx_list = [36]. It is good.
#
#
# Cs_000_Br_040_Pb_063_OLA_021_PF_010_Tol_620_20250608-193204_9d3865_scattering-1_mean_q.gr 0.75394
# Only found one corresponding uid idx_list = [41]. It is good.
#
#
# Cs_000_Br_142_Pb_091_OLA_006_PF_020_Tol_1200_20250608-185217_3486c9_scattering-1_mean_q.gr 0.581877
# Only found one corresponding uid idx_list = [39]. It is good.
#
#
# Cs_000_Br_143_Pb_093_OLA_000_PF_020_Tol_1182_20250608-205851_e5c3d6_scattering-1_mean_q.gr 0.540659
# Only found one corresponding uid idx_list = [42]. It is good.
#
#
# Cs_010_Br_136_Pb_093_OLA_000_PF_020_Tol_1195_20250608-173020_a5e8e9_scattering-1_mean_q2.gr 0.359031
# Only found one corresponding uid idx_list = [35]. It is good.
#
#
# Cs_012_Br_122_Pb_099_OLA_000_PF_017_Tol_1165_20250609-014557_70c3f8_scattering-1_mean_q2.gr 0.358438
# Only found one corresponding uid idx_list = [49]. It is good.
#
#
# Cs_032_Br_091_Pb_099_OLA_008_PF_016_Tol_1150_20250609-024558_4208be_scattering-1_mean_q.gr 0.420404
# Only found one corresponding uid idx_list = [52]. It is good.
#
#
# Cs_032_Br_095_Pb_099_OLA_005_PF_016_Tol_1155_20250609-020544_2a946a_scattering-1_mean_q.gr 0.311056
# Only found one corresponding uid idx_list = [50]. It is good.
#
#
# Cs_035_Br_089_Pb_075_OLA_020_PF_016_Tol_1095_20250609-030556_3d7ab3_scattering-1_mean_q2.gr 0.526983
# Only found one corresponding uid idx_list = [53]. It is good.
#
#
# Cs_041_Br_083_Pb_060_OLA_007_PF_014_Tol_955_20250609-022611_6b21cd_scattering-1_mean_q.gr 0.393756
# Only found one corresponding uid idx_list = [51]. It is good.
#
#
# Cs_045_Br_079_Pb_095_OLA_006_PF_016_Tol_1125_20250609-032547_15626c_scattering-1_mean_q.gr 0.421198
# Only found one corresponding uid idx_list = [54]. It is good.
#
#
# Cs_055_Br_069_Pb_115_OLA_008_PF_018_Tol_1235_20250609-034523_f353ff_scattering-1_mean_q.gr 0.493059
# Only found one corresponding uid idx_list = [55]. It is good.
#
#
# Cs_065_Br_059_Pb_135_OLA_003_PF_019_Tol_1310_20250609-040448_0b6ae6_scattering-1_mean_q.gr 0.481528
# Only found one corresponding uid idx_list = [56]. It is good.
#
#
# Cs_065_Br_064_Pb_082_OLA_022_PF_019_Tol_1167_20250608-212503_938911_scattering-1_mean_q.gr 0.566139
# Only found one corresponding uid idx_list = [43]. It is good.
#
#
# Cs_076_Br_120_Pb_095_OLA_000_PF_024_Tol_1452_20250608-183136_ded9a3_scattering-1_mean_q.gr 0.29968
# Only found one corresponding uid idx_list = [38]. It is good.
#
#
# Cs_078_Br_092_Pb_000_OLA_020_PF_016_Tol_948_20250608-191128_dc413d_scattering-1_mean_q.gr 0.199612
# Only found one corresponding uid idx_list = [40]. It is good.
#
#
# Cs_100_Br_040_Pb_000_OLA_003_PF_012_Tol_716_20250608-181233_717c6e_scattering-1_mean_q.gr 0.256612
# Only found one corresponding uid idx_list = [37]. It is good.
#
#
# Cs_100_Br_090_Pb_063_OLA_015_PF_019_Tol_1340_20250609-012613_804aeb_scattering-1_mean_q.gr 0.336232
# Only found one corresponding uid idx_list = [48]. It is good.
#
#
# Cs_110_Br_090_Pb_057_OLA_020_PF_023_Tol_1385_20250609-000751_b5be4a_scattering-1_mean_q.gr 0.364869
# Only found one corresponding uid idx_list = [44]. It is good.
#
#
# Cs_116_Br_074_Pb_050_OLA_012_PF_018_Tol_1260_20250609-002730_9f5fa3_scattering-1_mean_q.gr 0.356048
# Only found one corresponding uid idx_list = [45]. It is good.
#
#
# Cs_120_Br_050_Pb_060_OLA_005_PF_017_Tol_1175_20250609-004713_3acff7_scattering-1_mean_q.gr 0.378455
# Only found one corresponding uid idx_list = [46]. It is good.
#
#
# Cs_130_Br_050_Pb_044_OLA_014_PF_017_Tol_1190_20250609-010653_4a9843_scattering-1_mean_q.gr 0.430649
# Only found one corresponding uid idx_list = [47]. It is good.
#
#
# Cs_060_Br_120_Pb_060_PF_020_Tol_1200_20250606-233737_992618_scattering-1_mean_q.gr 0.262076
# Only found one corresponding uid idx_list = [5]. It is good.
#
#
# Cs_015_Br_070_Pb_016_OLA_005_PF_009_Tol_530_20250610-035232_0718dd_scattering-1_mean_q.gr 0.421519
# Only found one corresponding uid idx_list = [84]. It is good.
#
#
# Cs_015_Br_075_Pb_010_OLA_002_PF_008_Tol_510_20250610-005832_1b0770_scattering-1_mean_q.gr 0.157225
# Only found one corresponding uid idx_list = [77]. It is good.
#
#
# Cs_016_Br_080_Pb_006_OLA_018_PF_010_Tol_600_20250610-001750_315214_scattering-1_mean_q.gr 0.223023
# Only found one corresponding uid idx_list = [75]. It is good.
#
#
# Cs_020_Br_070_Pb_022_OLA_000_PF_009_Tol_560_20250610-053836_a9aa8a_scattering-1_mean_q.gr 0.283056
# Only found one corresponding uid idx_list = [89]. It is good.
#
#
# Cs_020_Br_085_Pb_022_OLA_001_PF_011_Tol_640_20250610-041311_acc484_scattering-1_mean_q.gr 0.292649
# Only found one corresponding uid idx_list = [85]. It is good.
#
#
# Cs_025_Br_075_Pb_025_OLA_010_PF_011_Tol_675_20250610-045357_bf9914_scattering-1_mean_q.gr 0.408539
# Only found one corresponding uid idx_list = [87]. It is good.
#
#
# Cs_027_Br_090_Pb_040_OLA_000_PF_013_Tol_785_20250609-211638_291d1d_scattering-1_mean_q.gr 0.205972
# Only found one corresponding uid idx_list = [67]. It is good.
#
#
# Cs_028_Br_078_Pb_029_OLA_000_PF_011_Tol_673_20250609-205333_44c93f_scattering-1_mean_q.gr 0.222444
# Only found one corresponding uid idx_list = [66]. It is good.
#
#
# Cs_028_Br_079_Pb_029_OLA_000_PF_011_Tol_682_20250610-043330_58afe3_scattering-1_mean_q.gr 0.257327
# Only found one corresponding uid idx_list = [86]. It is good.
#
#
# Cs_030_Br_090_Pb_040_OLA_015_PF_015_Tol_875_20250609-231619_1ec05d_scattering-1_mean_q.gr 0.232199
# Only found one corresponding uid idx_list = [72]. It is good.
#
#
# Cs_030_Br_150_Pb_020_OLA_010_PF_018_Tol_1050_20250610-003646_86af6b_scattering-1_mean_q.gr 0.171194
# Only found one corresponding uid idx_list = [76]. It is good.
#
#
# Cs_031_Br_162_Pb_011_OLA_036_PF_020_Tol_1197_20250609-235551_ea83af_scattering-1_mean_q.gr 0.243753
# Only found one corresponding uid idx_list = [74]. It is good.
#
#
# Cs_032_Br_092_Pb_040_OLA_002_PF_014_Tol_830_20250609-233714_bf8e84_scattering-1_mean_q.gr 0.193461
# Only found one corresponding uid idx_list = [73]. It is good.
#
#
# Cs_033_Br_141_Pb_080_OLA_002_PF_021_Tol_1280_20250609-175317_8364d6_scattering-1_mean_q.gr 0.286205
# Only found one corresponding uid idx_list = [57]. It is good.
#
#
# Cs_035_Br_082_Pb_030_OLA_005_PF_013_Tol_760_20250609-215803_746b39_scattering-1_mean_q.gr 0.203475
# Only found one corresponding uid idx_list = [69]. It is good.
#
#
# Cs_035_Br_085_Pb_040_OLA_002_PF_014_Tol_810_20250610-051525_1785b6_scattering-1_mean_q.gr 0.356649
# Only found one corresponding uid idx_list = [88]. It is good.
#
#
# Cs_035_Br_160_Pb_036_OLA_010_PF_020_Tol_1205_20250610-033002_c8114c_scattering-1_mean_q.gr 0.456707
# Only found one corresponding uid idx_list = [83]. It is good.
#
#
# Cs_037_Br_070_Pb_030_OLA_002_PF_012_Tol_695_20250609-213805_2e9a36_scattering-1_mean_q.gr 0.199022
# Only found one corresponding uid idx_list = [68]. It is good.
#
#
# Cs_040_Br_100_Pb_055_OLA_000_PF_016_Tol_975_20250609-225648_fcded6_scattering-1_mean_q.gr 0.200619
# Only found one corresponding uid idx_list = [71]. It is good.
#
#
# Cs_041_Br_170_Pb_044_OLA_000_PF_021_Tol_1275_20250610-023453_8d176d_scattering-1_mean_q.gr 0.157742
# Only found one corresponding uid idx_list = [82]. It is good.
#
#
# Cs_043_Br_131_Pb_083_OLA_000_PF_021_Tol_1285_20250609-181255_d95074_scattering-1_mean_q.gr 0.270221
# Only found one corresponding uid idx_list = [58]. It is good.
#
#
# Cs_050_Br_045_Pb_020_OLA_002_PF_010_Tol_585_20250610-021626_c2b71e_scattering-1_mean_q.gr 0.186939
# Only found one corresponding uid idx_list = [81]. It is good.
#
#
# Cs_053_Br_121_Pb_086_OLA_000_PF_022_Tol_1300_20250609-183232_157555_scattering-1_mean_q.gr 0.27442
# Only found one corresponding uid idx_list = [59]. It is good.
#
#
# Cs_054_Br_102_Pb_063_OLA_020_PF_020_Tol_1195_20250609-191158_757e04_scattering-1_mean_q.gr 0.4479
# Only found one corresponding uid idx_list = [61]. It is good.
#
#
# Cs_059_Br_104_Pb_058_OLA_017_PF_020_Tol_1190_20250609-193150_d50931_scattering-1_mean_q.gr 0.404083
# Only found one corresponding uid idx_list = [62]. It is good.
#
#
# Cs_063_Br_111_Pb_089_OLA_000_PF_022_Tol_1315_20250609-185207_c202cd_scattering-1_mean_q.gr 0.303323
# Only found one corresponding uid idx_list = [60]. It is good.
#
#
# Cs_064_Br_106_Pb_053_OLA_014_PF_020_Tol_1185_20250609-195143_5d181d_scattering-1_mean_q.gr 0.365978
# Only found one corresponding uid idx_list = [63]. It is good.
#
#
# Cs_069_Br_108_Pb_048_OLA_011_PF_020_Tol_1180_20250609-201135_95b2c2_scattering-1_mean_q.gr 0.338735
# Only found one corresponding uid idx_list = [64]. It is good.
#
#
# Cs_074_Br_110_Pb_043_OLA_008_PF_020_Tol_1175_20250609-203129_12cfba_scattering-1_mean_q.gr 0.288902
# Only found one corresponding uid idx_list = [65]. It is good.
#
#
# Cs_082_Br_200_Pb_118_OLA_000_PF_033_Tol_1996_20250609-221542_fc4b69_scattering-1_mean_q.gr 0.222852
# Only found one corresponding uid idx_list = [70]. It is good.
#
#
# Cs_101_Br_070_Pb_040_OLA_002_PF_018_Tol_1065_20250610-013630_922f95_scattering-1_mean_q.gr 0.206643
# Only found one corresponding uid idx_list = [79]. It is good.
#
#
# Cs_114_Br_082_Pb_033_OLA_000_PF_019_Tol_1144_20250610-011735_ff2a42_scattering-1_mean_q.gr 0.191966
# Only found one corresponding uid idx_list = [78]. It is good.
#
#
# Cs_120_Br_090_Pb_025_OLA_005_PF_020_Tol_1200_20250610-015508_1e9846_scattering-1_mean_q.gr 0.191396
# Only found one corresponding uid idx_list = [80]. It is good.

# %%
rw_array
# Out:
# array([0.498661, 0.421203, 0.326182, 0.376581, 0.233113, 0.262076,
#        0.267686, 0.171292, 0.126442, 0.451138, 0.609117, 0.11297 ,
#        0.116686, 0.427648, 0.290175, 0.49738 , 0.443992, 0.362031,
#        0.39817 , 0.358669, 0.453689, 0.236434, 0.454671, 0.305446,
#        0.205521, 0.228118, 0.357139, 0.325553, 0.323024, 0.297829,
#        0.321884, 0.348258, 0.215812, 0.251361, 0.257464, 0.359031,
#        0.776852, 0.256612, 0.29968 , 0.581877, 0.199612, 0.75394 ,
#        0.540659, 0.566139, 0.364869, 0.356048, 0.378455, 0.430649,
#        0.336232, 0.358438, 0.311056, 0.393756, 0.420404, 0.526983,
#        0.421198, 0.493059, 0.481528, 0.286205, 0.270221, 0.27442 ,
#        0.303323, 0.4479  , 0.404083, 0.365978, 0.338735, 0.288902,
#        0.222444, 0.205972, 0.199022, 0.203475, 0.222852, 0.200619,
#        0.232199, 0.193461, 0.243753, 0.223023, 0.171194, 0.157225,
#        0.191966, 0.206643, 0.191396, 0.186939, 0.157742, 0.456707,
#        0.421519, 0.292649, 0.257327, 0.408539, 0.356649, 0.283056])

# %%
ddp_uid_array
# Out:
# array(['c1a394', '9e13eb', 'd03d55', 'a26ebc', '2047e3', '992618',
#        '4d8520', 'e4b5eb', 'db00fc', 'd0b4bc', '6129b4', '854c30',
#        '860dbf', '99c5e0', '7ac162', '8b795a', '50fbde', '2ea4da',
#        '26d97d', 'ed358a', '91db25', '61ff18', 'ee525f', '6c0aea',
#        'ca1d54', '5cd92f', '620d4e', 'e65c02', 'd0803c', '0bfd55',
#        '629b0d', 'e27e88', 'c172aa', '08e90c', '4cd305', 'a5e8e9',
#        '4e1986', '717c6e', 'ded9a3', '3486c9', 'dc413d', '9d3865',
#        'e5c3d6', '938911', 'b5be4a', '9f5fa3', '3acff7', '4a9843',
#        '804aeb', '70c3f8', '2a946a', '6b21cd', '4208be', '3d7ab3',
#        '15626c', 'f353ff', '0b6ae6', '8364d6', 'd95074', '157555',
#        'c202cd', '757e04', 'd50931', '5d181d', '95b2c2', '12cfba',
#        '44c93f', '291d1d', '2e9a36', '746b39', 'fc4b69', 'fcded6',
#        '1ec05d', 'bf8e84', 'ea83af', '315214', '86af6b', '1b0770',
#        'ff2a42', '922f95', '1e9846', 'c2b71e', '8d176d', 'c8114c',
#        '0718dd', 'acc484', '58afe3', 'bf9914', '1785b6', 'a9aa8a'],
#       dtype=StringDType())

# %%
check_uid
# Out:
# ['3ae92b', 'cd7e20']

# %%
xlsx_fit = pd.DataFrame()
xlsx_fit['rw'] = rw_array
xlsx_fit['CsBr wt%'] = CsBr_array
xlsx_fit['Cs4PbBr6 wt%'] = Cs4PbBr6_array
xlsx_fit['CsPbBr3 wt%'] = CsPbBr3_array
xlsx_fit['uid_in_ddp'] = ddp_uid_array
xlsx_fit['chi_name'] = fn_array

# %%
xlsx_dir = '/Users/cheng-hunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/LDRD_PQDs_log'
xlsx_name = 'blop_test_20250725.xlsx'
xlsx_fit.to_excel(xlsx_fn, sheet_name='20250725_pdffit2')
