# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import mpld3 
from scipy import integrate  
import scipy.signal as scipy


from numpy import diff
from numpy import gradient
from scipy.optimize import curve_fit
import seaborn as sns
sns.set_theme()
sns.set(style="ticks", rc={"lines.linewidth": 0.9})
import cycler
n = 20
color = plt.cm.viridis(np.linspace(0, 1,n))
plt.rcParams['axes.prop_cycle'] = cycler.cycler('color', color)
plt.rcParams['figure.figsize'] = (3.25,3.25)
plt.rcParams['font.size'] = '12'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rc('lines', linewidth=1.5)
mpld3.enable_notebook()
# %matplotlib notebook
# %cd /Users/matthewgreenberg/Documents/NB1_110
mpld3.enable_notebook()
plt.gcf().subplots_adjust(bottom=0.25)
plt.gcf().subplots_adjust(left=0.25)

def gauss(x, H, A, x0, sigma):
    return H + A * np.exp(-(x - x0) ** 2 / (2 * sigma ** 2))
def gauss_fit(x, y):
    mean = sum(x * y) / sum(y)
    sigma = np.sqrt(sum(y * (x - mean) ** 2) / sum(y))
    popt, pcov = curve_fit(gauss, x, y, p0=[min(y), max(y), mean, sigma])
    return popt

Wavelength = []
fwhm = []
Amplitude = []
IntegratedPl = []
Br = list(range(25,500,25))
Br = [x/1000 for x in Br]
print(Br)

def load_fldatab(x,y):
    for n in range(x,y,20):
        (wave,pl) = np.loadtxt('Fluor_Subt11__'+str(n+20)+'__'+str(n+20)+'.txt', skiprows=14, delimiter='\t', unpack='true')
        plt.xlabel('Wavelength (nm)')
        plt.ylabel('PL Intensity (Counts)')
        wave=wave[300:500]
        pl=pl[300:500]
        plt.plot(wave,pl,label='3:1 Br:CsPb')
        H, A, x0, sigma = gauss_fit(wave,pl)
        Wavelength.append(x0)
        FWHM = 2.355*sigma 
        Integral = integrate.simps(pl,wave)
        IntegratedPl.append(Integral)
        fwhm.append(FWHM)
        Amplitude.append(A)
        
       
        
       
            



load_fldatab(0,180)
load_fldatab(201,400)




print(IntegratedPl)
# Out:
# /Users/matthewgreenberg/Documents/NB1_110
# <img src="data:image/png;base64,..." width="325">
# [0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475]
# [135899.4306864848, 118139.84039068938, 113311.00011653658, 121058.80006909229, 108038.46969191826, 126942.48984391951, 121310.88630330638, 120496.8829282241, 140417.07706171888, 129945.76821649299, 125446.12847666974, 124968.88996911718, 87038.4749785475, 97259.20479054002, 86043.33283507414, 73698.77436135865, 80048.58823038089, 68233.01406548137, 60363.39074224269]

# %%
mpld3.enable_notebook()
# %matplotlib notebook
plt.plot(Br,fwhm,'o')
plt.xlabel('Br2 Flow Rate')
plt.ylabel(r'$\sigma$')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="425">

# %%
mpld3.enable_notebook()
# %matplotlib notebook
plt.plot(Br,Amplitude,'o')
plt.tight_layout()
plt.xlabel('Br2 Flow Rate')
plt.ylabel(r'Amplitude')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="425">

# %%
# %matplotlib notebook
# %cd /Users/matthewgreenberg/Documents/NB1_110

Ab_365 = []
Ab_400 = []

def load_absdatab(x,y):
    for n in range(x,y,20):
        (wave,ab) = np.loadtxt('Abs_Absorbance__'+str(n+20)+'__'+str(n+20)+'.txt', skiprows=14, delimiter='\t', unpack='true')
        plt.xlabel('Wavelength (nm)')
        plt.ylabel('Absorbance')
        Ab_365.append(ab[212])
        Ab_400.append(ab[257])
        wave=wave[200:600]
        ab=ab[200:600]
        plt.plot(wave,ab,'o', markersize=1,)
        plt.tight_layout()


load_absdatab(0,380)
print(Ab_365)
print(Ab_400)
# Out:
# /Users/matthewgreenberg/Documents/NB1_110
# <img src="data:image/png;base64,..." width="325">
# [0.94, 1.06, 1.18, 1.35, 1.74, 1.83, 1.84, 1.89, 2.0, 2.02, 2.05, 2.1, 2.08, 2.09, 2.09, 2.09, 2.12, 2.15, 2.17]
# [0.57, 0.66, 0.73, 0.84, 1.14, 1.24, 1.24, 1.29, 1.41, 1.45, 1.5, 1.56, 1.53, 1.55, 1.56, 1.55, 1.62, 1.64, 1.68]

# %%
mpld3.enable_notebook()
# %matplotlib notebook
plt.plot(Br,IntegratedPl,'bo')
plt.tight_layout()
plt.xlabel('Br2 Flow Rate')
plt.ylabel(r'IntegratedPL')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="325">

# %%
mpld3.enable_notebook()
# %matplotlib notebook
RePLQY = [x/y for x,y in zip(IntegratedPl,Ab_365)]
plt.rcParams['figure.figsize'] = (3.25,3.25)
plt.plot(Br,RePLQY/max(RePLQY), 'bo')
plt.tight_layout()
plt.xlabel('Br2 Flow Rate')
plt.ylabel(r'Rel. PLQY')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="325">

# %%
plt.rcParams['figure.figsize'] = (3.25,3.25)
plt.rcParams['font.size'] = '12'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rc('lines', linewidth=1.5)
mpld3.enable_notebook()
# %matplotlib notebook

plt.gcf().subplots_adjust(bottom=0.25)
plt.gcf().subplots_adjust(left=0.25)
#
ConcCsPbBr3 = [(1000*x*2.30)/(87000*.1016*.121) for x in Ab_400]
plt.plot(Br,ConcCsPbBr3, 'ro')

plt.xlabel('Br2 Flow Rate')
plt.ylabel(r'Concentration CsPbBr3 (mM)')
# Out:
# <img src="data:image/png;base64,..." width="325">
# Text(0, 0.5, 'Concentration CsPbBr3 (mM)')
