# %%
import glob
import os

import matplotlib as mpl
import matplotlib.pyplot as plt
# import mpld3 
import seaborn as sns
import palettable.colorbrewer.diverging as pld
# import palettable.lightbartlein.diverging as pld

import numpy as np
import pandas as pd
# from sklearn import preprocessing

from scipy import integrate
# import scipy.signal as scipy
from scipy.optimize import curve_fit
# from scipy.signal import find_peaks

# %matplotlib widget

# %%
plt.close('all')

# %%
## Plotting parameters

palette = pld.RdYlGn_4_r
# palette = pld.BlueGreen_4_r
# palette = pld.Spectral_10_r
cmap = palette.mpl_colormap
# cmap = plt.get_cmap('rainbow')
transparency = 0.7
labelsize = 20
spinewidth = 3
fontsize = 26
legendsize = 20
fontweight = 'bold'
labelpad = 6
pad = 10
linewidth = 2.5

# %%
cmap

# %% [markdown]
# # Reading Uv-Vis data in .csv

# %% [markdown]
# ## Find the subfolders in the current working folder (cwd)

# %%
#cwd = os.getcwd()
# cwd = '/nsls2/users/clin1/Documents/Cheng-Hung/temp/20221108_insitu'
cwd = '/Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/UVVIS_OceanView/20230829_OceanView_cuvette'
subfolder = glob.glob(cwd + '/Abs**')
subfolder.sort()
# subfolder_Abs = glob.glob(cwd + '/quinine**Abs**')
# subfolder_Abs.sort()
# subfolder_Cl.reverse()
# del subfolder[-1]
print(*subfolder, sep = '\n')  ## Print one element per line
# print(*subfolder_Abs, sep = '\n')  ## Print one element per line
# Out:
# /Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/UVVIS_OceanView/20230829_OceanView_cuvette/Abs-In-BX_PL-In-SR_out-SR
# /Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/UVVIS_OceanView/20230829_OceanView_cuvette/Abs-In-SR_PL-In-SR_out-BX
# /Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/UVVIS_OceanView/20230829_OceanView_cuvette/Abs-In-SR_PL-In-SR_out-SR

# %%
fiber_list = [os.path.basename(i) for i in subfolder]
fiber_list
# Out:
# ['Abs-In-BX_PL-In-SR_out-SR',
#  'Abs-In-SR_PL-In-SR_out-BX',
#  'Abs-In-SR_PL-In-SR_out-SR']

# %% [markdown]
# # Flurorescence (PL)

# %% [markdown]
# ## Read PL data into pandas dataframe

# %%
# df_x = pd.DataFrame()
# df_int = pd.DataFrame()
df = pd.DataFrame()
quinine_con = ['1E-4', '2E-4']
fiber_list2 = ['Abs-BX_out-SR', 'Abs-SR_out-BX', 'Abs-SR_out-SR']

for i in range(len(subfolder)):
    for j in range(len(quinine_con)):
        # data_files = subfolder
        data_files = glob.glob(subfolder[i] + f'/{quinine_con[j]}**Subt**')
        data_files.sort()
        # del data_files[0]
        # suffix = os.path.basename(subfolder_PL[i])
        suffix = quinine_con[j] + '_' + fiber_list2[i]
        # id0 = 8
        # id1 = 22

        skiprows = 14 ## skip 23 rows if data processed by dioptas or ## 8
        df_int = pd.DataFrame()
        df_temp = pd.DataFrame()

        for k in range(len(data_files)):        
            df_int = pd.read_csv(data_files[k], skiprows=skiprows, sep='\t', names=['Wavelength', f'PL_{k:03d}'])
            df_temp = pd.concat([df_temp, df_int[f'PL_{k:03d}']], axis=1, ignore_index=False)
        
        # df_temp[f'{suffix}_mean'] = df_temp.mean(axis=1)
        # df_temp = pd.read_csv(data_files[i], skiprows=skiprows, sep=',')
        df[f'x_{suffix}'] = df_int['Wavelength']
        df[f'{suffix}_mean'] = df_temp.mean(axis=1)

# %%
df
# Out:
#       x_1E-4_Abs-BX_out-SR  1E-4_Abs-BX_out-SR_mean  x_2E-4_Abs-BX_out-SR  \
# 0                  197.742                 0.112222               197.742
# 1                  198.544                 0.170000               198.544
# 2                  199.347                 0.376667               199.347
# 3                  200.149                 0.421111               200.149
# 4                  200.951                 0.238889               200.951
# ...                    ...                      ...                   ...
# 1039               990.770                -0.105556               990.770
# 1040               991.489                -0.070000               991.489
# 1041               992.208                 0.063333               992.208
# 1042               992.928                -0.027778               992.928
# 1043               993.647                -0.112222               993.647
#
#       2E-4_Abs-BX_out-SR_mean  x_1E-4_Abs-SR_out-BX  1E-4_Abs-SR_out-BX_mean  \
# 0                    0.230000               197.742                -0.287778
# 1                    0.258889               198.544                -0.141111
# 2                    0.482222               199.347                 0.097778
# 3                    0.420000               200.149                 0.274444
# 4                    0.184444               200.951                 0.146667
# ...                       ...                   ...                      ...
# 1039                -0.317778               990.770                 0.368889
# 1040                -0.180000               991.489                 0.168889
# 1041                -0.062222               992.208                 0.092222
# 1042                -0.161111               992.928                 0.152222
# 1043                -0.230000               993.647                 0.287778
#
#       x_2E-4_Abs-SR_out-BX  2E-4_Abs-SR_out-BX_mean  x_1E-4_Abs-SR_out-SR  \
# 0                  197.742                -0.248889               197.742
# 1                  198.544                -0.080000               198.544
# 2                  199.347                 0.102222               199.347
# 3                  200.149                 0.265556               200.149
# 4                  200.951                 0.072222               200.951
# ...                    ...                      ...                   ...
# 1039               990.770                 0.208889               990.770
# 1040               991.489                 0.091111               991.489
# 1041               992.208                -0.045556               992.208
# 1042               992.928                 0.098889               992.928
# 1043               993.647                 0.248889               993.647
#
#       1E-4_Abs-SR_out-SR_mean  x_2E-4_Abs-SR_out-SR  2E-4_Abs-SR_out-SR_mean
# 0                    0.034444               197.742                -0.157778
# 1                    0.116667               198.544                 0.177778
# 2                    0.401111               199.347                 0.434444
# 3                    0.478889               200.149                 0.604444
# 4                    0.418889               200.951                 0.484444
# ...                       ...                   ...                      ...
# 1039                -0.142222               990.770                 0.210000
# 1040                -0.037778               991.489                 0.088889
# 1041                 0.023333               992.208                -0.030000
# 1042                 0.035556               992.928                 0.085556
# 1043                -0.034444               993.647                 0.157778
#
# [1044 rows x 12 columns]

# %% [markdown]
# ## Check data in pd dataframe

# %%
df.keys()
# Out:
# Index(['x_1E-4_Abs-BX_out-SR', '1E-4_Abs-BX_out-SR_mean',
#        'x_2E-4_Abs-BX_out-SR', '2E-4_Abs-BX_out-SR_mean',
#        'x_1E-4_Abs-SR_out-BX', '1E-4_Abs-SR_out-BX_mean',
#        'x_2E-4_Abs-SR_out-BX', '2E-4_Abs-SR_out-BX_mean',
#        'x_1E-4_Abs-SR_out-SR', '1E-4_Abs-SR_out-SR_mean',
#        'x_2E-4_Abs-SR_out-SR', '2E-4_Abs-SR_out-SR_mean'],
#       dtype='object')

# %%
df.shape
# Out:
# (1044, 12)

# %% [markdown]
# ## Prepare keys for average scans in pd dataframe

# %%
keys_list = list(df.keys())
# k1 = [k for k in keys_list if 'mean' in k]
keys_list
# Out:
# ['x_1E-4_Abs-BX_out-SR',
#  '1E-4_Abs-BX_out-SR_mean',
#  'x_2E-4_Abs-BX_out-SR',
#  '2E-4_Abs-BX_out-SR_mean',
#  'x_1E-4_Abs-SR_out-BX',
#  '1E-4_Abs-SR_out-BX_mean',
#  'x_2E-4_Abs-SR_out-BX',
#  '2E-4_Abs-SR_out-BX_mean',
#  'x_1E-4_Abs-SR_out-SR',
#  '1E-4_Abs-SR_out-SR_mean',
#  'x_2E-4_Abs-SR_out-SR',
#  '2E-4_Abs-SR_out-SR_mean']

# %%
# title = [os.path.basename(subfolder[i]) for i in range(len(subfolder))]
title = keys_list[1::2]
print(*title, sep='\n')

# label1 = ['quinine_1E-4M', 'quinine_2E-4M', 'quinine_5E-4M']
#          # 'Insitu CsPb 6mM + Br 6 mM + ZnI2 128uL/min']

# label2 = ['200ms', '300ms']
#          # 'ZnI2 128 uL/min']
# Out:
# 1E-4_Abs-BX_out-SR_mean
# 2E-4_Abs-BX_out-SR_mean
# 1E-4_Abs-SR_out-BX_mean
# 2E-4_Abs-SR_out-BX_mean
# 1E-4_Abs-SR_out-SR_mean
# 2E-4_Abs-SR_out-SR_mean

# %% [markdown]
# ## Plot all PL scans together

# %%
f1, ax1 = plt.subplots(1, 1, figsize = (8, 4), constrained_layout=True)
# f1, (ax1, ax2) = plt.subplots(1, 2, figsize = (6, 9), gridspec_kw={'width_ratios': [1,1]})

label = title
k = len(title)
color_idx = np.linspace(0, 1, k)
linestyle = ['solid', 'dashed', 'solid', 'dashed', 'solid', 'dashed']
id0 = 8
id1 = 18

for i in range(len(title)):
    # ax1.plot(df_tth.iloc[:,i], df_int[k1[i]]+offset*i, color=cmap(color_idx[i]), label=label[i])
    ax1.plot(df[keys_list[i*2]], df[keys_list[i*2+1]], linestyle=linestyle[i], color=cmap(color_idx[i]), label=label[i][:id1])

legend_properties = {'weight':'bold', 'size':10}    
ax1.legend(prop=legend_properties)

# ax1.set_xlim(-0.5, 20)
# ax1.set_ylim(2500, 9500)
# ax1.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# ax1.set_ylabel('Intensity', fontsize=16, fontweight='regular')
ax1.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
spinewidth = 1.5
ax1.spines["bottom"].set_linewidth(spinewidth)
ax1.spines["right"].set_linewidth(spinewidth)
ax1.spines["top"].set_linewidth(spinewidth)
ax1.spines["left"].set_linewidth(spinewidth)

imag_name = '20221228_ZnI2_tth_01.png'
# cwd = '/Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/20221127_Cl_Br_I'
# plt.savefig(cwd + '/' + imag_name, dpi = 600,  transparent=True)


### Define integrate range ###
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx, array[idx]

wavelength_range = [390, 750]
idx_w0, w0 = find_nearest(df[keys_list[0]], wavelength_range[0])
idx_w1, w1 = find_nearest(df[keys_list[0]], wavelength_range[1])

ax1.axvline(w0)
ax1.axvline(w1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot PL scans accroding to the Fiber type

# %%
f12, ax12 = plt.subplots(1, 3, figsize = (9, 3), constrained_layout=True)
# f1, (ax1, ax2) = plt.subplots(1, 2, figsize = (6, 9), gridspec_kw={'width_ratios': [1,1]})

label = quinine_con
# k = len(title)
# color_idx = np.linspace(0, 1, k)

id0 = 8
id1 = 18

for i in range(len(fiber_list2)):
    for j in range(len(quinine_con)):
        suffix = quinine_con[j] + '_' + fiber_list2[i] 
        ax12[i].plot(df[f'x_{suffix}'], df[f'{suffix}_mean'], label=label[j])
    ax12[i].set_title(fiber_list2[i])
    ax12[i].set_ylim(-30, 650)
    ax12[i].set_xlim(300, 800)

    legend_properties = {'weight':'bold', 'size':10}    
    ax12[i].legend(prop=legend_properties)

# ax1.set_xlim(-0.5, 20)
# ax1.set_ylim(2500, 9500)
# ax1.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# ax1.set_ylabel('Intensity', fontsize=16, fontweight='regular')
# ax1.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
# spinewidth = 1.5
# ax1.spines["bottom"].set_linewidth(spinewidth)
# ax1.spines["right"].set_linewidth(spinewidth)
# ax1.spines["top"].set_linewidth(spinewidth)
# ax1.spines["left"].set_linewidth(spinewidth)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Create new folder "plqy" for saving data

# %%
new_dir = cwd + '/plqy'

try:
    os.mkdir(new_dir)
except FileExistsError:
    pass

# if os.path.exists(new_dir):
#     pass
# else:
#     os.mkdir(new_dir)

# %% [markdown]
# ## Integrate peak area

# %%
simpson_int = []
for i in range(len(title)):
    x = df[keys_list[i*2]][idx_w0:idx_w1]
    y = df[keys_list[i*2+1]][idx_w0:idx_w1]
    simpson_int.append(integrate.simpson(y, x))

df_int = pd.DataFrame()
df_int['Data_source'] = [title[i] for i in range(len(title))]
df_int['Simpson_integrate'] = simpson_int
df_int
# Out:
#                Data_source  Simpson_integrate
# 0  1E-4_Abs-BX_out-SR_mean       63344.787674
# 1  2E-4_Abs-BX_out-SR_mean       53160.137210
# 2  1E-4_Abs-SR_out-BX_mean       23807.654528
# 3  2E-4_Abs-SR_out-BX_mean       19846.226886
# 4  1E-4_Abs-SR_out-SR_mean       53198.678771
# 5  2E-4_Abs-SR_out-SR_mean       45639.075152

# %% [markdown]
# ## Save Simpson integrate of PL peak

# %%
# df_int.to_csv(os.path.join(new_dir, 'simpson_integrate.csv'), index=False, sep=',', float_format='{:.8e}'.format)

# %%
# df_int.to_csv('Quinine_cuvette_simpson_integrate.txt', index=False, sep=' ', float_format='{:.5e}'.format)

# %% [markdown]
# # Absorbance

# %% [markdown]
# ### Read Abs data into pandas dataframe

# %%
# df_x = pd.DataFrame()
# df_int = pd.DataFrame()
df2 = pd.DataFrame()
quinine_con = ['1E-4', '2E-4']
fiber_list2 = ['Abs-BX_out-SR', 'Abs-SR_out-BX', 'Abs-SR_out-SR']

for i in range(len(subfolder)):
    for j in range(len(quinine_con)):
        # data_files = subfolder
        data_files = glob.glob(subfolder[i] + f'/{quinine_con[j]}**Absorbance**')
        data_files.sort()
        # del data_files[0]
        # suffix = os.path.basename(subfolder_PL[i])
        suffix = quinine_con[j] + '_' + fiber_list2[i]
        # id0 = 8
        # id1 = 22

        skiprows = 14 ## skip 23 rows if data processed by dioptas or ## 8
        df_int = pd.DataFrame()
        df_temp = pd.DataFrame()

        for k in range(len(data_files)):        
            df_int = pd.read_csv(data_files[k], skiprows=skiprows, sep='\t', names=['Wavelength', f'PL_{k:03d}'])
            df_temp = pd.concat([df_temp, df_int[f'PL_{k:03d}']], axis=1, ignore_index=False)
        
        # df_temp[f'{suffix}_mean'] = df_temp.mean(axis=1)
        # df_temp = pd.read_csv(data_files[i], skiprows=skiprows, sep=',')
        df2[f'x_{suffix}'] = df_int['Wavelength']
        df2[f'{suffix}_mean'] = df_temp.mean(axis=1)

# %%
df2
# Out:
#       x_1E-4_Abs-BX_out-SR  1E-4_Abs-BX_out-SR_mean  x_2E-4_Abs-BX_out-SR  \
# 0                  197.742                 0.006667               197.742
# 1                  198.544                 0.242222               198.544
# 2                  199.347                 0.238889               199.347
# 3                  200.149                 0.240000               200.149
# 4                  200.951                 0.240000               200.951
# ...                    ...                      ...                   ...
# 1039               990.770                -0.010000               990.770
# 1040               991.489                -0.010000               991.489
# 1041               992.208                -0.010000               992.208
# 1042               992.928                -0.010000               992.928
# 1043               993.647                 0.006667               993.647
#
#       2E-4_Abs-BX_out-SR_mean  x_1E-4_Abs-SR_out-BX  1E-4_Abs-SR_out-BX_mean  \
# 0                    0.006667               197.742                -0.008889
# 1                    0.275556               198.544                 0.376667
# 2                    0.267778               199.347                 0.366667
# 3                    0.268889               200.149                 0.368889
# 4                    0.270000               200.951                 0.370000
# ...                       ...                   ...                      ...
# 1039                -0.010000               990.770                 0.000000
# 1040                -0.010000               991.489                 0.000000
# 1041                -0.010000               992.208                 0.000000
# 1042                -0.010000               992.928                 0.000000
# 1043                 0.006667               993.647                -0.008889
#
#       x_2E-4_Abs-SR_out-BX  2E-4_Abs-SR_out-BX_mean  x_1E-4_Abs-SR_out-SR  \
# 0                  197.742                     0.01               197.742
# 1                  198.544                     0.44               198.544
# 2                  199.347                     0.43               199.347
# 3                  200.149                     0.43               200.149
# 4                  200.951                     0.43               200.951
# ...                    ...                      ...                   ...
# 1039               990.770                     0.00               990.770
# 1040               991.489                     0.00               991.489
# 1041               992.208                     0.00               992.208
# 1042               992.928                     0.00               992.928
# 1043               993.647                     0.01               993.647
#
#       1E-4_Abs-SR_out-SR_mean  x_2E-4_Abs-SR_out-SR  2E-4_Abs-SR_out-SR_mean
# 0                   -0.001111               197.742                -0.007778
# 1                    0.400000               198.544                 0.460000
# 2                    0.390000               199.347                 0.450000
# 3                    0.390000               200.149                 0.450000
# 4                    0.390000               200.951                 0.450000
# ...                       ...                   ...                      ...
# 1039                 0.000000               990.770                 0.000000
# 1040                 0.000000               991.489                 0.000000
# 1041                 0.000000               992.208                 0.000000
# 1042                 0.000000               992.928                 0.000000
# 1043                -0.001111               993.647                -0.007778
#
# [1044 rows x 12 columns]

# %% [markdown]
# ## Prepare keys for average scans in pd dataframe

# %%
keys_list2 = list(df2.keys())
# k1 = [k for k in keys_list if 'mean' in k]
keys_list2
# Out:
# ['x_1E-4_Abs-BX_out-SR',
#  '1E-4_Abs-BX_out-SR_mean',
#  'x_2E-4_Abs-BX_out-SR',
#  '2E-4_Abs-BX_out-SR_mean',
#  'x_1E-4_Abs-SR_out-BX',
#  '1E-4_Abs-SR_out-BX_mean',
#  'x_2E-4_Abs-SR_out-BX',
#  '2E-4_Abs-SR_out-BX_mean',
#  'x_1E-4_Abs-SR_out-SR',
#  '1E-4_Abs-SR_out-SR_mean',
#  'x_2E-4_Abs-SR_out-SR',
#  '2E-4_Abs-SR_out-SR_mean']

# %%
# title = [os.path.basename(subfolder_Abs[i]) for i in range(len(subfolder_Abs))]
title = keys_list2[1::2]
print(*title, sep='\n')

# label1 = ['quinine_1E-4M', 'quinine_2E-4M', 'quinine_5E-4M']
#          # 'Insitu CsPb 6mM + Br 6 mM + ZnI2 128uL/min']

# label2 = ['200ms', '300ms']
#          # 'ZnI2 128 uL/min']
# Out:
# 1E-4_Abs-BX_out-SR_mean
# 2E-4_Abs-BX_out-SR_mean
# 1E-4_Abs-SR_out-BX_mean
# 2E-4_Abs-SR_out-BX_mean
# 1E-4_Abs-SR_out-SR_mean
# 2E-4_Abs-SR_out-SR_mean

# %% [markdown]
# ## Plot all Abs scans together

# %%
f2, ax2 = plt.subplots(1, 1, figsize = (8, 4), constrained_layout=True)
# f1, (ax1, ax2) = plt.subplots(1, 2, figsize = (6, 9), gridspec_kw={'width_ratios': [1,1]})

label = title
k = len(title)
color_idx = np.linspace(0, 1, k)
linestyle = ['solid', 'dashed', 'solid', 'dashed', 'solid', 'dashed']
id0 = 8
id1 = 18

for i in range(len(title)):
    # ax2.plot(df_tth.iloc[:,i], df_int[k1[i]]+offset*i, color=cmap(color_idx[i]), label=label[i])
    ax2.plot(df2[keys_list[i*2]], df2[keys_list[i*2+1]], linestyle=linestyle[i], color=cmap(color_idx[i]), label=label[i][:id1])

legend_properties = {'weight':'bold', 'size':10}    
ax2.legend(prop=legend_properties)

# ax2.set_xlim(-0.5, 20)
# ax2.set_ylim(2500, 9500)
# ax2.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# ax2.set_ylabel('Intensity', fontsize=16, fontweight='regular')
ax2.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
spinewidth = 1.5
ax2.spines["bottom"].set_linewidth(spinewidth)
ax2.spines["right"].set_linewidth(spinewidth)
ax2.spines["top"].set_linewidth(spinewidth)
ax2.spines["left"].set_linewidth(spinewidth)

imag_name = '20221228_ZnI2_tth_01.png'
# cwd = '/Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/20221127_Cl_Br_I'
# plt.savefig(cwd + '/' + imag_name, dpi = 600,  transparent=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot Abs scans accroding to the Fiber type

# %%
f22, ax22 = plt.subplots(1, 3, figsize = (9, 3), constrained_layout=True)
# f1, (ax1, ax2) = plt.subplots(1, 2, figsize = (6, 9), gridspec_kw={'width_ratios': [1,1]})

label = quinine_con
# k = len(title)
# color_idx = np.linspace(0, 1, k)

id0 = 8
id1 = 18

for i in range(len(fiber_list2)):
    for j in range(len(quinine_con)):
        suffix = quinine_con[j] + '_' + fiber_list2[i] 
        ax22[i].plot(df2[f'x_{suffix}'], df2[f'{suffix}_mean'], label=label[j])
    ax22[i].set_title(fiber_list2[i])
    # ax22[i].set_ylim(-30, 650)
    ax22[i].set_xlim(160, 460)

    legend_properties = {'weight':'bold', 'size':10}    
    ax22[i].legend(prop=legend_properties)

# ax1.set_xlim(-0.5, 20)
# ax1.set_ylim(2500, 9500)
# ax1.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# ax1.set_ylabel('Intensity', fontsize=16, fontweight='regular')
# ax1.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
# spinewidth = 1.5
# ax1.spines["bottom"].set_linewidth(spinewidth)
# ax1.spines["right"].set_linewidth(spinewidth)
# ax1.spines["top"].set_linewidth(spinewidth)
# ax1.spines["left"].set_linewidth(spinewidth)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Try linear fitting

# %%
def line_2D(x, slope, y_intercept):
    y = x*slope + y_intercept
    return y


def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx, array[idx]

def fit_line_2D(x, y, fit_function, x_range=[500, 900], maxfev=10000, plot=True):
    x = np.asarray(x)
    y = np.asarray(y)
    y = np.nan_to_num(y, nan=0)
    
    try:        
        idx0, _ = find_nearest(x, x_range[0])
        idx1, _ = find_nearest(x, x_range[1])
    except (TypeError, IndexError):
        idx0 = 0
        idx1 = -1
    
    slope = (y[idx1]-y[idx0]) / (x[idx1]-x[idx0])
    y_intercept = np.mean(y[idx0:idx1])
    
    try:
        initial_guess = [slope, y_intercept]
    except (TypeError, IndexError):
        initial_guess = [0.01, 0]
    
    try:
        popt, pcov = curve_fit(fit_function, x[idx0:idx1], y[idx0:idx1], p0=initial_guess, maxfev=maxfev)
    except RuntimeError:
        maxfev=1000000
        popt, pcov = curve_fit(fit_function, x[idx0:idx1], y[idx0:idx1], p0=initial_guess, maxfev=maxfev)
        
    if plot:
        plt.figure()
        plt.plot(x, y, label='data')
        plt.plot(x, fit_function(x, popt[0], popt[1]), label=f'y={popt[0]:.4f}x+{popt[1]:.4f}')
        plt.legend()
    
    return popt, pcov

# %%
x = df2[keys_list2[-2]]
y = df2[keys_list2[-1]]
x_range=[500, 900]
idx0, v0 = find_nearest(x, x_range[0])
idx1, v1 = find_nearest(x, x_range[1])
popt, pcov = fit_line_2D(x,y,line_2D, x_range=[500, 900])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
rows = 3
cols = 2
f3, ax3 = plt.subplots(rows, cols, figsize = (10, 9), constrained_layout=True)

label = title
title_reshape = np.asarray(title).reshape(rows, cols)
color_idx = np.linspace(0, 1, len(title))
id0 = 8
id1 = 22
x_range_list = [[500, 900], [600, 900], 
                [600, 900], [600, 900], 
                [400, 900], [800, 900],
               ]

legend_properties = {'weight':'bold', 'size':10}
df4 = pd.DataFrame()
for i in range(len(title)):
    # ax1.plot(df_tth.iloc[:,i], df_int[k1[i]]+offset*i, color=cmap(color_idx[i]), label=label[i])
    idx_ax = np.argwhere(title_reshape==title[i])
    x = df2[keys_list2[i*2]]
    y = df2[keys_list2[i*2+1]]
    popt, pcov = fit_line_2D(x, y, line_2D, x_range=x_range_list[0], plot=False)
    ax3[idx_ax[0][0], idx_ax[0][1]].plot(x, y, color=cmap(color_idx[i]), label=label[i][:id1])
    ax3[idx_ax[0][0], idx_ax[0][1]].plot(x, line_2D(x, popt[0], popt[1]), label=f'y={popt[0]:.4f}x+{popt[1]:.4f}')
    ax3[idx_ax[0][0], idx_ax[0][1]].legend(prop=legend_properties)
    
    df4[keys_list2[i*2]] = x
    # df4[keys_list2[i*2+1]] = y - popt[1]
    df4[keys_list2[i*2+1]] = y - line_2D(x, *popt)
    

# # ax3.set_xlim(-0.5, 20)
# # ax3.set_ylim(2500, 9500)
# # ax3.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# # ax3.set_ylabel('Intensity', fontsize=16, fontweight='regular')
# ax3.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
# spinewidth = 1.5
# ax3.spines["bottom"].set_linewidth(spinewidth)
# ax3.spines["right"].set_linewidth(spinewidth)
# ax3.spines["top"].set_linewidth(spinewidth)
# ax3.spines["left"].set_linewidth(spinewidth)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot Abs by offset

# %%
f4, ax4 = plt.subplots(1, 1, figsize = (10, 5), constrained_layout=True)
# f1, (ax1, ax2) = plt.subplots(1, 2, figsize = (6, 9), gridspec_kw={'width_ratios': [1,1]})

label = title
k = len(title)
color_idx = np.linspace(0, 1, k)
linestyle = ['solid', 'dashed', 'solid', 'dashed', 'solid', 'dashed']
id0 = 8
id1 = 18

for i in range(len(title)):
    # ax4.plot(df_tth.iloc[:,i], df_int[k1[i]]+offset*i, color=cmap(color_idx[i]), label=label[i])
    ax4.plot(df2[keys_list[i*2]], df2[keys_list[i*2+1]], linestyle=linestyle[i], color=cmap(color_idx[i]), label=label[i][:id1])

legend_properties = {'weight':'bold', 'size':10}    
ax4.legend(prop=legend_properties)

# ax4.set_xlim(-0.5, 20)
# ax4.set_ylim(2500, 9500)
# ax4.set_xlabel('tth (degree)', fontsize=16, fontweight='regular')
# ax4.set_ylabel('Intensity', fontsize=16, fontweight='regular')
ax4.tick_params(axis='both', direction='out', labelsize=12, size=4, width=1)
spinewidth = 1.5
ax4.spines["bottom"].set_linewidth(spinewidth)
ax4.spines["right"].set_linewidth(spinewidth)
ax4.spines["top"].set_linewidth(spinewidth)
ax4.spines["left"].set_linewidth(spinewidth)

imag_name = '20221228_ZnI2_tth_01.png'
# cwd = '/Users/chenghunglin/Library/CloudStorage/OneDrive-BrookhavenNationalLaboratory/data_processing/20221127_Cl_Br_I'
# plt.savefig(cwd + '/' + imag_name, dpi = 600,  transparent=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Prepare keys for offset data in pd dataframe

# %%
keys_list4 = list(df4.keys())
# k1 = [k for k in keys_list if 'mean' in k]
keys_list4
# Out:
# ['x_1E-4_Abs-BX_out-SR',
#  '1E-4_Abs-BX_out-SR_mean',
#  'x_2E-4_Abs-BX_out-SR',
#  '2E-4_Abs-BX_out-SR_mean',
#  'x_1E-4_Abs-SR_out-BX',
#  '1E-4_Abs-SR_out-BX_mean',
#  'x_2E-4_Abs-SR_out-BX',
#  '2E-4_Abs-SR_out-BX_mean',
#  'x_1E-4_Abs-SR_out-SR',
#  '1E-4_Abs-SR_out-SR_mean',
#  'x_2E-4_Abs-SR_out-SR',
#  '2E-4_Abs-SR_out-SR_mean']

# %% [markdown]
# ## Save offset data as csv

# %%
for i in range(len(title)):
    df_temp = pd.DataFrame()
    df_temp['Wavelength'] = df4[keys_list4[i*2]].fillna(0)
    df_temp['Absorbance'] = df4[keys_list4[i*2+1]].fillna(0)
    fn = title[i][:id1] + '_offset.csv'
    print(fn)
    # df_temp.to_csv(os.path.join(new_dir, fn), index=False, sep=',', float_format='{:.8e}'.format)
# Out:
# 1E-4_Abs-BX_out-SR_offset.csv
# 2E-4_Abs-BX_out-SR_offset.csv
# 1E-4_Abs-SR_out-BX_offset.csv
# 2E-4_Abs-SR_out-BX_offset.csv
# 1E-4_Abs-SR_out-SR_offset.csv
# 2E-4_Abs-SR_out-SR_offset.csv

# %% [markdown]
# ## Save Absorbance at 365 nm

# %%
idx_365, w365 = find_nearest(df4[keys_list2[0]], 365)
# df4.iloc[idx_365][::-2][::-1].to_list()

df_365 = pd.DataFrame()
df_365['Data_source'] = [title[i] for i in range(len(title))]
df_365['Abs_365'] = df2.iloc[idx_365][1::2].to_list()
df_365['Abs_offset_365'] = df4.iloc[idx_365][1::2].to_list()
df_365
# Out:
#                Data_source  Abs_365  Abs_offset_365
# 0  1E-4_Abs-BX_out-SR_mean     0.29        0.299260
# 1  2E-4_Abs-BX_out-SR_mean     0.58        0.578205
# 2  1E-4_Abs-SR_out-BX_mean     0.30        0.300000
# 3  2E-4_Abs-SR_out-BX_mean     0.59        0.586879
# 4  1E-4_Abs-SR_out-SR_mean     0.30        0.300000
# 5  2E-4_Abs-SR_out-SR_mean     0.59        0.584257

# %%
# df_365.to_csv(os.path.join(new_dir, 'abs_365.csv'), index=False, sep=',', float_format='{:.8e}'.format)

# %%
# df_365.to_csv('Quinine_cuvette_abs_365.txt', index=False, sep=' ', float_format='{:.5e}'.format)

# %%
df2.keys()
# Out:
# Index(['x_1E-4_Abs-BX_out-SR', '1E-4_Abs-BX_out-SR_mean',
#        'x_2E-4_Abs-BX_out-SR', '2E-4_Abs-BX_out-SR_mean',
#        'x_1E-4_Abs-SR_out-BX', '1E-4_Abs-SR_out-BX_mean',
#        'x_2E-4_Abs-SR_out-BX', '2E-4_Abs-SR_out-BX_mean',
#        'x_1E-4_Abs-SR_out-SR', '1E-4_Abs-SR_out-SR_mean',
#        'x_2E-4_Abs-SR_out-SR', '2E-4_Abs-SR_out-SR_mean'],
#       dtype='object')

# %% [markdown]
# ## Export quinine 2E-4M of 200ms for PLQY_summary.ipynb

# %%
# df_66 = pd.DataFrame()

# df_66['Wavelength_01'] = df['x_2E-4M_200ms']
# df_66['quinine_0.2mM_PL'] = df['2E-4M_200ms_mean']
# df_66['Wavelength_02'] = df2['x_2E-4M_200ms']
# df_66['quinine_0.2mM_Abs'] = df2['2E-4M_200ms_mean']

# df_66.to_csv('20230822_quinine_2E-4M.txt', index=False, sep=' ', float_format='{:.5e}'.format)
